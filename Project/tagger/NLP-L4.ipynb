# %% [markdown]
# # L4: Part-of-speech tagging

# %% [markdown]
# Part-of-speech tagging is the task of labelling the words (tokens) of a sentence with parts-of-speech such as noun, adjective, and verb. In this lab you will implement the simple, autoregressive fixed-window tagger that was presented in Lecture&nbsp;4.2.

# %% [markdown]
# ## The data set

# %% [markdown]
# The data set for the lab is the English Web Treebank from the [Universal Dependencies Project](http://universaldependencies.org), a corpus containing more than 16,000 sentences (254,000&nbsp;tokens) annotated with, among other things, parts-of-speech. The Universal Dependencies Project distributes its data in the [CoNLL-U format](https://universaldependencies.org/format.html), but for this lab we have converted the data into a simpler format: words and their part-of-speech tags are separated by tabs, sentences are separated by empty lines. The code in the next cell defines a container class for data with this format.

# %%
class Dataset():

    def __init__(self, filename):
        self.filename = filename

    def __iter__(self):
        tmp = []
        with open(self.filename, 'rt', encoding='utf-8') as lines:
            for line in lines:
                line = line.rstrip()
                if line:
                    tmp.append(tuple(line.split('\t')))
                else:
                    yield tmp
                    tmp = []

# %% [markdown]
# We load the training data and the development data for this lab:

# %%
train_data = Dataset('train.txt')
dev_data = Dataset('dev.txt')

# %% [markdown]
# Both data sets consist of **tagged sentences**. On the Python side of things, a tagged sentence is represented as a list of string pairs, where the first component of each pair represents a word token and the second component represents the word’s tag. The possible tags are listed and exemplified in the [Annotation Guidelines](http://universaldependencies.org/u/pos/all.html) of the Universal Dependencies Project. Run the next code cell to see an example of a tagged sentence.

# %%
print(list(train_data)[42])
print(list(dev_data)[42])
# Out:
# [('There', 'PRON'), ('has', 'AUX'), ('been', 'VERB'), ('talk', 'NOUN'), ('that', 'SCONJ'), ('the', 'DET'), ('night', 'NOUN'), ('curfew', 'NOUN'), ('might', 'AUX'), ('be', 'AUX'), ('implemented', 'VERB'), ('again', 'ADV'), ('.', 'PUNCT')]
# [('We', 'PRON'), ("'ve", 'AUX'), ('grown', 'VERB'), ('up', 'ADP'), ('.', 'PUNCT')]

# %% [markdown]
# ## Tagger interface

# %% [markdown]
# The tagger that you will implement in this lab follows a simple interface with just one method:

# %%
class Tagger(object):

    def predict(self, sentence):
        raise NotImplementedError

# %% [markdown]
# The single method of this interface has the following specification:
#
# **predict** (*self*, *sentence*)
#
# > Returns the list of predicted tags (a list of strings) for a single *sentence* (a list of string tokens).
#
# One trivial implementation of this interface is a tagger that always predicts the same tag for every word, independently of the input:

# %%
class ConstantTagger(Tagger):
    
    def __init__(self, the_tag):
        self.the_tag = the_tag
    
    def predict(self, words):
        return [self.the_tag] * len(words)

# %% [markdown]
# ## Problem 1: Implement an evaluation function

# %% [markdown]
# Your first task is to implement a function that computes the accuracy of a tagger on gold-standard data.

# %%
def accuracy(tagger, gold_data):
    # TODO: Replace the next line with your own code
    tot = 0
    correct = 0

    for words in gold_data:
        tot += len(words)
        gold_tags = [i[1] for i in words]
        gold_words = [i[0] for i in words]
        pred_tags = tagger.predict(gold_words)
        #print(gold_tags, " ", pred_tags)
        correct += sum(1 for x,y in zip(gold_tags,pred_tags) if x == y)
    
    return correct / tot

# %%
const_tagger = ConstantTagger('NOUN')

acc = accuracy(const_tagger, dev_data)
acc
# Out:
# 0.1668919993637665

# %% [markdown]
# Your implementation should conform to the following specification:
#
# **accuracy** (*tagger*, *gold_data*)
#
# > Computes the accuracy of the *tagger* on the gold-standard data *gold_data* (an iterable of tagged sentences) and returns it as a float. Recall that the accuracy is defined as the percentage of tokens to which the tagger assigns the correct tag (as per the gold standard).

# %% [markdown]
# ### 🤞 Test your code
#
# Test your code by computing the accuracy on the development set of a trivial tagger that tags each word as a noun. The expected value is 16.69%.

# %% [markdown]
# ## Problem 2: Implement a baseline

# %% [markdown]
# Before you start working on the tagger as such, we ask you to first implement a simple baseline:
#
# > Tag each input word with the most frequent tag for that word in the training data. If an input word does not occur in the training data, tag it with the overall most frequent tag in the training data. Break ties by choosing that tag which comes first in the alphabetical order.
#
# To implement the baseline, you need to implement both a class `BaselineTagger` and a function `train_baseline`. A `BaselineTagger` has two fields: a dictionary mapping each word in the training data to the most frequent tag for that word, and a string representing the fallback tag (overall most frequent tag in the training data). Both of these fields are set in the `train_baseline` function.

# %%
class BaselineTagger(Tagger):

    def __init__(self):
        self.most_frequent = {}
        self.fallback = None

    def predict(self, words):
        # TODO: Replace the next line with your own code
        res = []
        for word in words:
            if word in self.most_frequent:
                res.append(self.most_frequent[word])
            else:
                res.append(self.fallback)
        #print(words)
        #print(res)
        return res


def train_baseline(train_data):
    # TODO: Replace the next line with your own code

    ret = BaselineTagger()

    temp = {}
    fallback = {}

    all_words = set()

    for sent in train_data:
        for word_and_tag in sent:
            if word_and_tag in temp:
                temp[word_and_tag] += 1
            else:
                temp[word_and_tag] = 1
            
            if word_and_tag[1] in fallback:
                fallback[word_and_tag[1]] += 1
            else:
                fallback[word_and_tag[1]] = 1

            all_words.add(word_and_tag[0])


    most_frequent = {}
    for word in all_words:
        best_tag = ''
        freq = 0
        for word_and_tag, occ in temp.items():
            if word == word_and_tag[0]:
                if occ > freq:
                    best_tag = word_and_tag[1]
                    freq = occ
        most_frequent[word] = best_tag

    
    #print(most_frequent)
    ret.most_frequent = most_frequent
    ret.fallback = max(fallback, key=fallback.get)
    return ret

# %%
baseline_tagger = train_baseline(train_data)

# %%
acc = accuracy(baseline_tagger, dev_data)
acc
# Out:
# 0.8564100524892636

# %% [markdown]
# ### 🤞 Test your code
#
# Test your implementation by computing the accuracy of the baseline tagger on the development data. The expected value is 85.61%.

# %% [markdown]
# ## Problem 3: Create the vocabularies

# %% [markdown]
# As in previous labs, you will need an explicit representation of your vocabulary. Here we actually have two vocabularies: one for the words and one for the tags. Both should be represented as dictionaries that map words/tags to a contiguous range of integers, starting at zero.
#
# The next cell contains skeleton code for a function `make_vocabs` that constructs the two vocabularies from gold-standard data. The code cell also defines a name for the ‘unknown word’ (`UNK`) and for an additional pseudoword that you will use as a placeholder for undefined values (`PAD`).

# %%
PAD = '<pad>'
UNK = '<unk>'

def make_vocabs(gold_data):
    #print(list(gold_data))

    words = {}
    tags = {}

    curr_word_idx = 2
    curr_tag_idx = 1

    words[PAD] = 0
    words[UNK] = 1

    tags[PAD] = 0

    for sent in list(gold_data):
        for word, tag in sent:
            if word not in words:
                words[word] = curr_word_idx
                curr_word_idx += 1
            
            if tag not in tags:
                tags[tag] = curr_tag_idx
                curr_tag_idx += 1

    return words, tags

# %%
words, tags = make_vocabs(train_data)

print(len(words))
print(len(tags))
# Out:
# 19674
# 18

# %% [markdown]
# Complete the code according to the following specification:
#
# **make_vocabs** (*gold_data*)
#
# > Returns a pair of dictionaries mapping the unique words and tags in the gold-standard data *gold_data* (an iterable over tagged sentences) to contiguous ranges of integers starting at zero. The word dictionary contains the pseudowords `PAD` (index&nbsp;0) and `UNK` (index&nbsp;1); the tag dictionary contains `PAD` (index&nbsp;0).

# %% [markdown]
# ### 🤞 Test your code
#
# Test your implementation by computing the total number of unique words and tags in the training data (including the pseudowords). The expected values are 19,674&nbsp;words and 18&nbsp;tags.

# %% [markdown]
# ## Problem 4: Fixed-window tagger

# %% [markdown]
# Your main task in this lab is to implement a complete, autoregressive part-of-speech tagger based on the fixed-window architecture. This implementation has four parts: the fixed-window model; a tagger that uses the fixed-window model to make predictions; a function that generates training examples for the tagger; and the training function.
#
# **⚠️ We expect that solving this problem will take you the longest time in this lab.**

# %% [markdown]
# ### Problem 4.1: Implement the fixed-window model

# %% [markdown]
# The architecture of the fixed-window model is presented in Lecture&nbsp;4.2. An input to the network takes the form of a $k$-dimensional vector of word ids and/or tag ids. Each integer $i$ is mapped to an $e_i$-dimensional embedding vector. These vectors are concatenated to form a vector of length $e_1 + \cdots + e_k$, and sent through a feed-forward network with a single hidden layer and a rectified linear unit (ReLU).
#
# #### Default features
#
# We ask you to implement a fixed-window model with the following features ($k=4$):
#
# 0. current word
# 1. previous word
# 2. next word
# 3. tag predicted for the previous word
#
# Whenever the value of a feature is undefined, you should use the special value `PAD`.
#
# #### Embedding specifications
#
# To make your implementation of the fixed-window model useful for a range of different applications (including the parser that you will build in lab&nbsp;5), it should support other feature sets than the default model. To this end, the constructor of your model should accept a list of what we call *embedding specifications*. An embedding specification is a triple $(m, n, e)$ consisting of three integers. Such a triple specifies that the model should include $m$ instances of an embedding from $n$ items to vectors of size $e$. All of the $m$ instances are to share their weights. In this lab, the embeddings will be embeddings for words and tags. For example, to instantiate the default feature model, you would initialise the model with the following specifications:
#
# ``
# [(3, num_words, word_dim), (1, num_tags, tag_dim)]
# ``
#
# This specifies that the model should use 3 instances of an embedding from *num_words* words to vectors of length *word_dim*, and 1 instance of an embedding from *num_tags* tags to vectors of length *tag_dim*. All 3 instances of the word embedding would share their weights. If you rather wanted to have word embeddings with separate weights, you would initialise the model with the following specifications:
#
# ``
# [(1, num_words, word_dim), (1, num_words, word_dim), (1, num_words, word_dim), (1, num_tags, tag_dim)]
# ``
#
# We recommend that you initialize the weights of each embedding with values drawn from $\mathcal{N}(0, 10^{-2})$.
#
# #### Hyperparameters
#
# The network architecture introduces a number of hyperparameters. The following choices are reasonable defaults:
#
# * width of each word embedding: 50
# * width of each tag embedding: 10
# * size of the hidden layer: 100

# %% [markdown]
# The next cell contains skeleton code for the implementation of the fixed-window model.

# %%
import torch.nn as nn
import torch

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

class FixedWindowModel(nn.Module):

    def __init__(self, embedding_specs, hidden_dim, output_dim):
        super().__init__()
        # TODO: Add your code here
        self.embedding_specs = embedding_specs
        self.embeddings = nn.ModuleList((nn.Embedding(i[1], i[2])) for i in embedding_specs for j in range(i[0]))  

        for embed in self.embeddings:
            nn.init.normal_(embed.weight,0, 0.01)

        glove = torch.load('glove.pt')
        for embed in self.embeddings:
          embed.from_pretrained(glove, freeze=False)

        self.linear1   = nn.Linear(50*3 + 10, hidden_dim)
        self.relu      = nn.ReLU()
        self.linear2   = nn.Linear(hidden_dim, output_dim)
        
    # Features is B x k where B == batch_size and k is total embeddings (k = 4, 3 word embs and 1 tag emb)
    def forward(self, features):
        # TODO: Replace the next line with your own code
        #print(self.embeddings)
        #print("feature size: ", features.size())

        rows=features.size()[0]
        cols=features.size()[1]
        feat_v = torch.empty(features.size()[0], 160)
        for row in range(0,rows):
            target_embedding = self.embeddings[0].weight[features[row][0]]
            for column in range(1,cols):
                word_embedding = self.embeddings[column].weight[features[row][column]]
                target_embedding = torch.cat((target_embedding, word_embedding),-1)
                #print("target_embedding size: ", target_embedding.size())
            feat_v[row] = target_embedding
        
        linear1 = self.linear1(feat_v)
        rel     = self.relu(linear1)
        output  = self.linear2(rel)   

        return output

# %%
test = FixedWindowModel([(3, len(words), 50), (1, len(tags), 10)], 100, 18)

#test.forward("asd")

# %% [markdown]
# Your implementation should meet the following specification:
#
# **__init__** (*self*, *embedding_specs*, *hidden_dim*, *output_dim*)
#
# > A fixed-window model is initialized with a list of specifications for the embeddings the network should use (*embedding_specs*), the size of the hidden layer (*hidden_dim*), and the size of the output layer (*output_dim*).
#
# **forward** (*self*, *features*)
#
# > Computes the network output for a given feature representation *features*. This is a tensor of shape $B \times k$ where $B$ is the batch size (number of samples in the batch) and $k$ is the total number of embeddings specified upon initialisation. For example, for the default feature model, $k=4$, as this model includes 3 (weight-sharing) word embeddings and 1 tag embedding.
#
# #### 💡 Hint on the implementation
#
# You will have to construct embeddings based on the embedding specifications. It is natural to store these embeddings in a list- or dictionary-valued attribute of the `FixedWindowModel` object. However, in order to expose the embeddings to the auto-differentiation magic of PyTorch (so that their weights are updated during training), you must instead store them in an [`nn.ModuleList`](https://pytorch.org/docs/stable/nn.html#torch.nn.ModuleList) or [`nn.ModuleDict`](https://pytorch.org/docs/stable/nn.html#torch.nn.ModuleDict).

# %% [markdown]
# ### Problem 4.2: Implement the tagger

# %% [markdown]
# The next step is to implement the tagger itself. The tagger will use the simple algorithm that was presented in Lecture&nbsp;4.2: It processes an input sentence from left to right, and at each position, predicts the tag for the current word based on the features extracted from the current feature window.

# %%
class FixedWindowTagger(Tagger):

    def __init__(self, vocab_words, vocab_tags, word_dim=50, tag_dim=10, hidden_dim=100):
        embedding_specs = [(3, len(vocab_words), word_dim), (1, len(vocab_tags), tag_dim)]

        self.vocab_words = vocab_words
        self.vocab_tags  = vocab_tags
        self.model = FixedWindowModel(embedding_specs, hidden_dim, len(vocab_tags))
        # TODO: Replace the next line with your own code
        pass

    def featurize(self, words, i, pred_tags):
        # TODO: Replace the next line with your own code
        # All cases
      if len(words) == 1: # If only one word is sent in
            return torch.LongTensor([words[i], 0, 0, 0])
      elif i == len(words) - 1: #If current word end of list
            return torch.LongTensor([words[i], words[i - 1], 0, pred_tags[i - 1]])
      elif i == 0: #If current word beginning of list
            return torch.LongTensor([words[i], 0, words[i + 1], 0])
      else:  # If middle of words
            return torch.LongTensor([words[i], words[i - 1], words[i + 1], pred_tags[i - 1]])

    def predict(self, words):
        # TODO: Replace the next line with your own code
        
        # Change the strings to word ids as vocabulary is ids. 0 == UNK
        word_ids = []
        for word in words:
              if word in self.vocab_words:
                    word_ids.append(self.vocab_words[word])
              else:
                    word_ids.append(0)

        predicted_tags = []
        for i in range(len(word_ids)):
              curr_feature = self.featurize(word_ids, i, predicted_tags)
              #print("feature: ", curr_feature.view(1,4))
              res = self.model.forward(curr_feature.view(1,4))
              not_used, tag = torch.max(res.squeeze(0), 0)
              #print("tag: ", tag)
              predicted_tags.append(tag)
        
        # Convert tag ids to strings
        predicted_tag_strings = []
        for pred_tag_id in predicted_tags:
          for key, val in self.vocab_tags.items():
                if val == pred_tag_id:
                      predicted_tag_strings.append(key)
                      
        return predicted_tag_strings

# %%
tagger = FixedWindowTagger(words, tags)
print(tagger.predict(["the","cat", "sat","on","the","floor"]))
#[words["the"], words["cat"]]
# Out:
# ['ADJ', 'ADJ', 'ADJ', 'ADJ', 'ADJ', 'ADJ']

# %% [markdown]
# Complete the skeleton code by implementing the methods of this interface:
#
# **__init__** (*self*, *vocab_words*, *vocab_tags*, *word_dim* = 50, *tag_dim* = 10, *hidden_dim* = 100)
#
# > Creates a new fixed-window model of appropriate dimensions and sets up any other data structures that you consider relevant. The parameters *vocab_words* and *vocab_tags* are the word vocabulary and tag vocabulary. The parameters *word_dim* and *tag_dim* specify the embedding width for the word embeddings and tag embeddings.
#
# **featurize** (*self*, *words*, *i*, *pred_tags*)
#
# > Extracts features from the specified tagger configuration according to the default feature model. The configuration is specified in terms of the words in the input sentence (*words*, a list of word ids), the position of the current word (*i*), and the list of already predicted tags (*pred_tags*, a list of tag ids). Returns a tensor that can be fed to the fixed-window model.
#
# **predict** (*self*, *words*)
#
# > Processes the input sentence *words* (a list of string tokens) and makes calls to the fixed-window model to predict the tag of each word. Returns the list of the predicted tags (strings).

# %% [markdown]
# ### Problem 4.3: Generate the training examples

# %% [markdown]
# Your next task is to implement a function that generates the training examples for the tagger. You will train the tagger as usual, using minibatch training.

# %%
def training_examples(vocab_words, vocab_tags, gold_data, tagger, batch_size=100):
    batch_x, batch_y = [], []

    for sentence in gold_data:
        word_ids = []
        tag_ids = []
        for word, tag in sentence:
            word_ids.append(vocab_words[word])
            tag_ids.append(vocab_tags[tag])

        for idx, tag in enumerate(tag_ids):
            feature = tagger.featurize(word_ids, idx, tag_ids)
            #print(feature, " word ids: ", word_ids, " tag ids: ", tag_ids)
            batch_x.append(feature)
            batch_y.append(tag)

            # If batch contains batch size examples, yield them and empty x and y.
            if len(batch_x) == batch_size:
                yield torch.stack(batch_x, dim=0), torch.LongTensor(batch_y)
                batch_x, batch_y = [], []
    
    # yield what we have in the end if not empty.
    #if len(batch_x) != 0:
    #    yield torch.stack(batch_x, dim=0), torch.LongTensor(batch_y)
        

tagger = FixedWindowTagger(words, tags)
for x, y in training_examples(words, tags, list(train_data), tagger):
  print(x.size())
  print(y.size())
  break
# Out:
# torch.Size([100, 4])
# torch.Size([100])

# %% [markdown]
# Your code should comply with the following specification:
#
# **training_examples** (*vocab_words*, *vocab_tags*, *gold_data*, *tagger*, *batch_size* = 100)
#
# > Iterates through the given *gold_data* (an iterable of tagged sentences), encodes it into word ids and tag ids using the specified vocabularies *vocab_words* and *vocab_tags*, and then yields batches of training examples for gradient-based training. Each batch contains *batch_size* examples, except for the last batch, which may contain fewer examples. Each example in the batch is created by a call to the `featurize` function of the *tagger*.

# %% [markdown]
# ### Problem 4.4: Training loop

# %% [markdown]
# What remains to be done is the implementation of the training loop. This should be a straightforward generalization of the training loops that you have seen so far. Complete the skeleton code in the cell below:

# %%
import torch.optim as optim
import torch.nn.functional as F

def train_fixed_window(train_data, n_epochs=1, batch_size=100, lr=1e-2):
    # TODO: Replace the next line with your own code
    tagger = FixedWindowTagger(words, tags)
    vocab_words, vocab_tags = make_vocabs(train_data)
    model = tagger.model
    optimizer = optim.Adam(model.parameters(), lr=lr)

    train_losses = []
  
    for epoch in range(n_epochs): 
        count = 1
        progress = 0
        train_loss = 0
        avg_loss = 0

        for x, y in training_examples(vocab_words, vocab_tags, train_data, tagger):
            model.train()
            optimizer.zero_grad()

            #Forward pass
            output = model.forward(x) #Expect float not long

            #Compute the loss
            loss = F.cross_entropy(output,  y) #Expect long not float
            train_loss += loss.item()
            progress += len(y)
            
            #clear_output()
            print("Running Train loss: " + str(train_loss/count))

            count += 1
            
            #Backward pass
            loss.backward()
            
            #Update the parameter of the model
            optimizer.step()

    return tagger

# %% [markdown]
# Here is the specification of the training function:
#
# **train_fixed_window** (*train_data*, *n_epochs* = 1, *batch_size* = 100, *lr* = 1e-2)
#
# > Trains a fixed-window tagger from a set of training data *train_data* (an iterable over tagged sentences) using minibatch gradient descent and returns it. The parameters *n_epochs* and *batch_size* specify the number of training epochs and the minibatch size, respectively. Training uses the cross-entropy loss function and the [Adam optimizer](https://pytorch.org/docs/stable/optim.html#torch.optim.Adam) with learning rate *lr*.

# %% [markdown]
# The next code cell trains a tagger and evaluates it on the development data:

# %%
tagger = train_fixed_window(train_data)
# Out:
# Running Train loss: 2.9012463092803955
# Running Train loss: 2.8808387517929077
# Running Train loss: 2.861061414082845
# Running Train loss: 2.8356871604919434
# Running Train loss: 2.8094598770141603
# Running Train loss: 2.7872949043909707
# Running Train loss: 2.7611547197614397
# Running Train loss: 2.7339400351047516
# Running Train loss: 2.6989080905914307
# Running Train loss: 2.664612889289856
# Running Train loss: 2.648386695168235
# Running Train loss: 2.613956113656362
# Running Train loss: 2.586440031345074
# Running Train loss: 2.547524537358965
# Running Train loss: 2.5046440760294595
# Running Train loss: 2.45341245085001
# Running Train loss: 2.4170870360206154
# Running Train loss: 2.373528348075019
# Running Train loss: 2.3311186526951038
# Running Train loss: 2.2902667939662935
# Running Train loss: 2.2433794736862183
# Running Train loss: 2.1858026602051477
# Running Train loss: 2.1489764866621597
# Running Train loss: 2.2092869132757187
# Running Train loss: 2.1666423749923704
# Running Train loss: 2.1293100531284628
# Running Train loss: 2.098064590383459
# Running Train loss: 2.0656248331069946
# Running Train loss: 2.0246774513145973
# Running Train loss: 1.9898834943771362
# Running Train loss: 1.9575122594833374
# Running Train loss: 1.9406927861273289
# Running Train loss: 1.9108810822168987
# Running Train loss: 1.8831797084387611
# Running Train loss: 1.8645504253251213
# Running Train loss: 1.8464024977551565
# Running Train loss: 1.8287212091523248
# Running Train loss: 1.8050694089186818
# Running Train loss: 1.7786580293606489
# Running Train loss: 1.755664113163948
# Running Train loss: 1.7359418752716809
# Running Train loss: 1.7104028094382513
# Running Train loss: 1.691258539987165
# Running Train loss: 1.6779365309260108
# Running Train loss: 1.6591292023658752
# Running Train loss: 1.6379506898962932
# Running Train loss: 1.6147946740718597
# Running Train loss: 1.5935204451282818
# Running Train loss: 1.5711967969427303
# Running Train loss: 1.5527605247497558
# Running Train loss: 1.5369800691511117
# Running Train loss: 1.5176701522790468
# Running Train loss: 1.5012554447605926
# Running Train loss: 1.482589159298826
# Running Train loss: 1.4681828233328733
# Running Train loss: 1.4557506458035536
# Running Train loss: 1.4429657725911391
# Running Train loss: 1.4294648987465892
# Running Train loss: 1.419322249747939
# Running Train loss: 1.4073210919896761
# Running Train loss: 1.3946212749989306
# Running Train loss: 1.3796123208538178
# Running Train loss: 1.3643120404273745
# Running Train loss: 1.3534267647191882
# Running Train loss: 1.3363494877631847
# Running Train loss: 1.3231231285767122
# Running Train loss: 1.3095888584407407
# Running Train loss: 1.2987137322916704
# Running Train loss: 1.2919201203014539
# Running Train loss: 1.2801924956696373
# Running Train loss: 1.2687731158565467
# Running Train loss: 1.2591400883264012
# Running Train loss: 1.2498017386214373
# Running Train loss: 1.2373639099501275
# Running Train loss: 1.2283559461434683
# Running Train loss: 1.2179893545414273
# Running Train loss: 1.208249516301341
# Running Train loss: 1.1985670179128647
# Running Train loss: 1.1897779616374005
# Running Train loss: 1.1817751865833999
# Running Train loss: 1.1751551396316953
# Running Train loss: 1.1694545698602026
# Running Train loss: 1.162340352693236
# Running Train loss: 1.1597709467723256
# Running Train loss: 1.1556697070598603
# Running Train loss: 1.1478607051594312
# Running Train loss: 1.158020658739682
# Running Train loss: 1.1564087183638052
# Running Train loss: 1.1488558914554252
# Running Train loss: 1.1437594185272852
# Running Train loss: 1.1395338698402866
# Running Train loss: 1.134280529683051
# Running Train loss: 1.128037775396019
# Running Train loss: 1.1213999298658777
# Running Train loss: 1.1128882257561934
# Running Train loss: 1.1084708105772734
# Running Train loss: 1.1032974302154226
# Running Train loss: 1.0970132971296505
# Running Train loss: 1.0936278237236872
# Running Train loss: 1.089538117647171
# Running Train loss: 1.0845903205399465
# Running Train loss: 1.07895426364506
# Running Train loss: 1.0729944078088964
# Running Train loss: 1.0672025511471124
# Running Train loss: 1.061661953017825
# Running Train loss: 1.0546356006613318
# Running Train loss: 1.047411963204357
# Running Train loss: 1.0400248723173584
# Running Train loss: 1.0356905724203915
# Running Train loss: 1.0308914684436539
# Running Train loss: 1.0258276292064168
# Running Train loss: 1.0203233524890882
# Running Train loss: 1.0150752548886612
# Running Train loss: 1.009621324115678
# Running Train loss: 1.0046786045250686
# Running Train loss: 1.0015176936727146
# Running Train loss: 0.9975252723337239
# Running Train loss: 0.993109670862303
# Running Train loss: 0.9917291754684529
# Running Train loss: 0.9884289285788933
# Running Train loss: 0.9842765507372943
# Running Train loss: 0.9795282200955954
# Running Train loss: 0.9775339841115765
# Running Train loss: 0.9792932648091547
# Running Train loss: 0.9814262753725052
# Running Train loss: 0.9782367912786347
# Running Train loss: 0.972594200508801
# Running Train loss: 0.9679877593880519
# Running Train loss: 0.9635765888663226
# Running Train loss: 0.9586924609083396
# Running Train loss: 0.9540694156903347
# Running Train loss: 0.950920050004215
# Running Train loss: 0.9490630045197064
# Running Train loss: 0.944007502229356
# Running Train loss: 0.9411573344910587
# Running Train loss: 0.9362682690296102
# Running Train loss: 0.9339720483896506
# Running Train loss: 0.9311773387202318
# Running Train loss: 0.9285778149212007
# Running Train loss: 0.925469435857875
# Running Train loss: 0.9217921496494442
# Running Train loss: 0.9193482437813786
# Running Train loss: 0.915195595655408
# Running Train loss: 0.9123826085900267
# Running Train loss: 0.9099850285669853
# Running Train loss: 0.9073039943428889
# Running Train loss: 0.9041822882128411
# Running Train loss: 0.9013682371257125
# Running Train loss: 0.8971346901767205
# Running Train loss: 0.8935604110360146
# Running Train loss: 0.8910210198716612
# Running Train loss: 0.8867188205844477
# Running Train loss: 0.8832694962133769
# Running Train loss: 0.8799356938182533
# Running Train loss: 0.8765289923837108
# Running Train loss: 0.8718014215238583
# Running Train loss: 0.8679170176671569
# Running Train loss: 0.8659391306057761
# Running Train loss: 0.8627054336123496
# Running Train loss: 0.8601519401185215
# Running Train loss: 0.8561145986274162
# Running Train loss: 0.8536137286343692
# Running Train loss: 0.8511819017628219
# Running Train loss: 0.8483139046626847
# Running Train loss: 0.8447288053505349
# Running Train loss: 0.8422591423234308
# Running Train loss: 0.8393621888167844
# Running Train loss: 0.8368781669331449
# Running Train loss: 0.8337531339311035
# Running Train loss: 0.8322262188090997
# Running Train loss: 0.8304761845988837
# Running Train loss: 0.8278325020747129
# Running Train loss: 0.8263828968898409
# Running Train loss: 0.8243686732375759
# Running Train loss: 0.822817331467356
# Running Train loss: 0.8198517439886928
# Running Train loss: 0.8169020617243934
# Running Train loss: 0.8134345134322563
# Running Train loss: 0.811631692521399
# Running Train loss: 0.8098540380597115
# Running Train loss: 0.8078370794077605
# Running Train loss: 0.8056487884822783
# Running Train loss: 0.804660321421962
# Running Train loss: 0.802096882754046
# Running Train loss: 0.800441468406368
# Running Train loss: 0.7978231647322255
# Running Train loss: 0.7958971351225745
# Running Train loss: 0.7945357456486276
# Running Train loss: 0.7943542057244235
# Running Train loss: 0.7940942058437749
# Running Train loss: 0.7922644329632764
# Running Train loss: 0.7907884637825191
# Running Train loss: 0.7905246857843251
# Running Train loss: 0.7900334355450168
# Running Train loss: 0.7891989452716631
# Running Train loss: 0.7869599394652308
# Running Train loss: 0.7846390493025029
# Running Train loss: 0.7855302703500998
# Running Train loss: 0.7840399268883557
# Running Train loss: 0.7820070357620716
# Running Train loss: 0.7800390686265272
# Running Train loss: 0.7799255483516372
# Running Train loss: 0.778424844953227
# Running Train loss: 0.7767882779532788
# Running Train loss: 0.7758958921199892
# Running Train loss: 0.7743932473138698
# Running Train loss: 0.7725926310831798
# Running Train loss: 0.7713611560085645
# Running Train loss: 0.7710009021907331
# Running Train loss: 0.7694020150672822
# Running Train loss: 0.7706496544641341
# Running Train loss: 0.7693536291426083
# Running Train loss: 0.7694950222689221
# Running Train loss: 0.768550625332048
# Running Train loss: 0.766887359425079
# Running Train loss: 0.7644575410005119
# Running Train loss: 0.7618139119054864
# Running Train loss: 0.7595828393593841
# Running Train loss: 0.7581274508749514
# Running Train loss: 0.7558821073309941
# Running Train loss: 0.7543713730250009
# Running Train loss: 0.7527202461082656
# Running Train loss: 0.7520993265736798
# Running Train loss: 0.7515798998065293
# Running Train loss: 0.7515413755178452
# Running Train loss: 0.7499403098383836
# Running Train loss: 0.7481934262136005
# Running Train loss: 0.7476764697124038
# Running Train loss: 0.7483649633206655
# Running Train loss: 0.7468992039561272
# Running Train loss: 0.7456231973258964
# Running Train loss: 0.7433974879697479
# Running Train loss: 0.7429034321732787
# Running Train loss: 0.7410866839126644
# Running Train loss: 0.7399775188654028
# Running Train loss: 0.738487624831624
# Running Train loss: 0.7372725407911253
# Running Train loss: 0.734754550294215
# Running Train loss: 0.7329160929599068
# Running Train loss: 0.731434755337735
# Running Train loss: 0.7298729045633459
# Running Train loss: 0.7286064081078718
# Running Train loss: 0.7285145725365039
# Running Train loss: 0.7265992137130166
# Running Train loss: 0.7241586251526463
# Running Train loss: 0.7225761662532644
# Running Train loss: 0.7209924764116766
# Running Train loss: 0.720096382102178
# Running Train loss: 0.7184859447809587
# Running Train loss: 0.7169718262553215
# Running Train loss: 0.7148991376755247
# Running Train loss: 0.713879051189574
# Running Train loss: 0.7117334810994831
# Running Train loss: 0.7105628629251728
# Running Train loss: 0.7088665183268341
# Running Train loss: 0.7069802779587917
# Running Train loss: 0.704886609652163
# Running Train loss: 0.7036049305353054
# Running Train loss: 0.7016431366499787
# Running Train loss: 0.6998509553762583
# Running Train loss: 0.6979776219504089
# Running Train loss: 0.6968523211037839
# Running Train loss: 0.6952999897669476
# Running Train loss: 0.6938789537120046
# Running Train loss: 0.6918871379685851
# Running Train loss: 0.6901322113616126
# Running Train loss: 0.6886849769492275
# Running Train loss: 0.6873973513494677
# Running Train loss: 0.6855569971538388
# Running Train loss: 0.683892552168281
# Running Train loss: 0.6822114251416548
# Running Train loss: 0.6808765769443091
# Running Train loss: 0.679551920502177
# Running Train loss: 0.6775328224919138
# Running Train loss: 0.6758993922038512
# Running Train loss: 0.6741235756679721
# Running Train loss: 0.6729031477916972
# Running Train loss: 0.6718349424090316
# Running Train loss: 0.6705375504429623
# Running Train loss: 0.6687024691275187
# Running Train loss: 0.6672748471494248
# Running Train loss: 0.6658312126677087
# Running Train loss: 0.6643709742559561
# Running Train loss: 0.6626610625272905
# Running Train loss: 0.6613119490836796
# Running Train loss: 0.6602067221607362
# Running Train loss: 0.6584667451290304
# Running Train loss: 0.656866647510065
# Running Train loss: 0.6556581406238582
# Running Train loss: 0.6541110667175261
# Running Train loss: 0.6524076400343904
# Running Train loss: 0.6516165630254027
# Running Train loss: 0.65090568155152
# Running Train loss: 0.6501829560313906
# Running Train loss: 0.648785848688271
# Running Train loss: 0.647571358578028
# Running Train loss: 0.6459904788720487
# Running Train loss: 0.6447972500284246
# Running Train loss: 0.6435432280585119
# Running Train loss: 0.6420415203770001
# Running Train loss: 0.6417546352476773
# Running Train loss: 0.6407332484493192
# Running Train loss: 0.6397385574606779
# Running Train loss: 0.6381959823989555
# Running Train loss: 0.636750172005325
# Running Train loss: 0.635106518085486
# Running Train loss: 0.6336192821640921
# Running Train loss: 0.6325795248924911
# Running Train loss: 0.6314832927918357
# Running Train loss: 0.6302109597671417
# Running Train loss: 0.6290251352491869
# Running Train loss: 0.6274652330634686
# Running Train loss: 0.6265443037397945
# Running Train loss: 0.6253838413365328
# Running Train loss: 0.6252493784068123
# Running Train loss: 0.6248468100741694
# Running Train loss: 0.6240484467722264
# Running Train loss: 0.6228763097955746
# Running Train loss: 0.6216164329395772
# Running Train loss: 0.6200933964923024
# Running Train loss: 0.6188675218096403
# Running Train loss: 0.6179710717304893
# Running Train loss: 0.6180793440009787
# Running Train loss: 0.6171130269397924
# Running Train loss: 0.6158391878238091
# Running Train loss: 0.6143320837498076
# Running Train loss: 0.6128944153313608
# Running Train loss: 0.611569077571536
# Running Train loss: 0.6100952937112029
# Running Train loss: 0.6091334973546592
# Running Train loss: 0.6079426502578208
# Running Train loss: 0.6066063135099339
# Running Train loss: 0.6054826133378275
# Running Train loss: 0.6042562370484104
# Running Train loss: 0.6029289878348806
# Running Train loss: 0.6021806349578712
# Running Train loss: 0.6006472210015671
# Running Train loss: 0.5995724991889748
# Running Train loss: 0.598440599806365
# Running Train loss: 0.5974393364042043
# Running Train loss: 0.5966546790472224
# Running Train loss: 0.595908702008034
# Running Train loss: 0.595741078453057
# Running Train loss: 0.5951031743397199
# Running Train loss: 0.5943450789304747
# Running Train loss: 0.5934103286981238
# Running Train loss: 0.5931165354696749
# Running Train loss: 0.5922000622055654
# Running Train loss: 0.5915609566350721
# Running Train loss: 0.5906037694854396
# Running Train loss: 0.5898369949555126
# Running Train loss: 0.5890978428916159
# Running Train loss: 0.5886250555979632
# Running Train loss: 0.5879758766268269
# Running Train loss: 0.5889443729754905
# Running Train loss: 0.5886127766054333
# Running Train loss: 0.5884115024566317
# Running Train loss: 0.587479336863623
# Running Train loss: 0.587718226347627
# Running Train loss: 0.5873714462543528
# Running Train loss: 0.5871913365999087
# Running Train loss: 0.5867049546490387
# Running Train loss: 0.5863717635759966
# Running Train loss: 0.5855724324195922
# Running Train loss: 0.5849636275270214
# Running Train loss: 0.5850020135483129
# Running Train loss: 0.5843983777171909
# Running Train loss: 0.5839493830040421
# Running Train loss: 0.5831671272957228
# Running Train loss: 0.5833439562570404
# Running Train loss: 0.5838386077243042
# Running Train loss: 0.5836766760956537
# Running Train loss: 0.5829499056887371
# Running Train loss: 0.5840028745724875
# Running Train loss: 0.5841885383725166
# Running Train loss: 0.583742715002216
# Running Train loss: 0.5840734236080704
# Running Train loss: 0.5836428127709835
# Running Train loss: 0.5835059284967294
# Running Train loss: 0.5826290679409316
# Running Train loss: 0.581687449607167
# Running Train loss: 0.5808098035138003
# Running Train loss: 0.580177806667964
# Running Train loss: 0.5794280805275775
# Running Train loss: 0.579018429482912
# Running Train loss: 0.5797897572460261
# Running Train loss: 0.5790954496162807
# Running Train loss: 0.5786617514821365
# Running Train loss: 0.5775897611497607
# Running Train loss: 0.5770658681598994
# Running Train loss: 0.5766329586010455
# Running Train loss: 0.5759913612499225
# Running Train loss: 0.575825141567462
# Running Train loss: 0.5750137845687757
# Running Train loss: 0.5740358561843256
# Running Train loss: 0.5737320955541699
# Running Train loss: 0.5730997257366288
# Running Train loss: 0.5725445115573742
# Running Train loss: 0.5721991459715337
# Running Train loss: 0.5721543857641518
# Running Train loss: 0.5717195067508263
# Running Train loss: 0.5709076272277394
# Running Train loss: 0.5701786583432784
# Running Train loss: 0.5696260855892802
# Running Train loss: 0.5687314957932189
# Running Train loss: 0.5692528631776718
# Running Train loss: 0.5689641683378442
# Running Train loss: 0.5685455249987689
# Running Train loss: 0.5683831212755229
# Running Train loss: 0.5675572556148215
# Running Train loss: 0.5671913362223736
# Running Train loss: 0.5666877093715864
# Running Train loss: 0.5662079999182761
# Running Train loss: 0.5657177931912567
# Running Train loss: 0.5654955962515739
# Running Train loss: 0.5649260610807687
# Running Train loss: 0.5642633193867098
# Running Train loss: 0.5636423112708701
# Running Train loss: 0.5630942659368094
# Running Train loss: 0.5624461417574258
# Running Train loss: 0.5615306604396986
# Running Train loss: 0.5613481455539923
# Running Train loss: 0.5611869285046068
# Running Train loss: 0.5606971527361926
# Running Train loss: 0.5604104753276881
# Running Train loss: 0.5601338794708531
# Running Train loss: 0.560037474739049
# Running Train loss: 0.5593112852842173
# Running Train loss: 0.5585351799438883
# Running Train loss: 0.5573813667390929
# Running Train loss: 0.5566861353849175
# Running Train loss: 0.5566966239345709
# Running Train loss: 0.5563177300776262
# Running Train loss: 0.556178863859877
# Running Train loss: 0.5560863267673158
# Running Train loss: 0.5552541914592506
# Running Train loss: 0.5547916677352084
# Running Train loss: 0.5547144300980519
# Running Train loss: 0.5562530484025054
# Running Train loss: 0.5555479212494736
# Running Train loss: 0.5555186846342082
# Running Train loss: 0.5566787138766698
# Running Train loss: 0.5561745656784581
# Running Train loss: 0.5569968050647829
# Running Train loss: 0.5564149750333823
# Running Train loss: 0.5560026086215347
# Running Train loss: 0.5552619600906068
# Running Train loss: 0.5543372029288938
# Running Train loss: 0.5537755925017502
# Running Train loss: 0.5532669453736808
# Running Train loss: 0.5531430761443406
# Running Train loss: 0.5525849367516626
# Running Train loss: 0.5525032059098316
# Running Train loss: 0.552014148469998
# Running Train loss: 0.5514549171777217
# Running Train loss: 0.5517098425495389
# Running Train loss: 0.5514984002634394
# Running Train loss: 0.5515547132762109
# Running Train loss: 0.5516488308853963
# Running Train loss: 0.5512113910249394
# Running Train loss: 0.5512300084169284
# Running Train loss: 0.5508284309709613
# Running Train loss: 0.5500860353187531
# Running Train loss: 0.5491943022091712
# Running Train loss: 0.5488829462678843
# Running Train loss: 0.5481737641609662
# Running Train loss: 0.5477408232522343
# Running Train loss: 0.5474238784060391
# Running Train loss: 0.54660044956023
# Running Train loss: 0.5464306010765598
# Running Train loss: 0.5457825921950447
# Running Train loss: 0.5449688497031013
# Running Train loss: 0.5445117181044931
# Running Train loss: 0.5438464694746813
# Running Train loss: 0.5435218443603892
# Running Train loss: 0.5429809320984142
# Running Train loss: 0.5423961225779926
# Running Train loss: 0.5419761300570172
# Running Train loss: 0.5412888187751765
# Running Train loss: 0.5411779242800548
# Running Train loss: 0.5410321088984082
# Running Train loss: 0.5403740103298574
# Running Train loss: 0.5399875755867233
# Running Train loss: 0.539319322028867
# Running Train loss: 0.538993680930322
# Running Train loss: 0.539103888274159
# Running Train loss: 0.538903006377345
# Running Train loss: 0.5389786224247368
# Running Train loss: 0.538263617871912
# Running Train loss: 0.5378729901371562
# Running Train loss: 0.5373183104253229
# Running Train loss: 0.5377198971611091
# Running Train loss: 0.5384814368285102
# Running Train loss: 0.5379618096433068
# Running Train loss: 0.5377078482222678
# Running Train loss: 0.5371759174797204
# Running Train loss: 0.5368250772371979
# Running Train loss: 0.5367369553874655
# Running Train loss: 0.5360609686491127
# Running Train loss: 0.5358531740233302
# Running Train loss: 0.5350679726285967
# Running Train loss: 0.5344138964639599
# Running Train loss: 0.5343597712547001
# Running Train loss: 0.533592492452867
# Running Train loss: 0.5326495046293972
# Running Train loss: 0.5317305323443277
# Running Train loss: 0.5307244161874997
# Running Train loss: 0.5299389278846169
# Running Train loss: 0.5300613784419705
# Running Train loss: 0.5301063086289693
# Running Train loss: 0.5295568903007795
# Running Train loss: 0.5291947419282224
# Running Train loss: 0.5290420506309289
# Running Train loss: 0.5291458322025169
# Running Train loss: 0.5315390478168587
# Running Train loss: 0.5314035042651113
# Running Train loss: 0.53112644252207
# Running Train loss: 0.5310284700280623
# Running Train loss: 0.5305176282656847
# Running Train loss: 0.5300487305216778
# Running Train loss: 0.5298979094291317
# Running Train loss: 0.529438896036896
# Running Train loss: 0.5289418462122547
# Running Train loss: 0.5282291231484985
# Running Train loss: 0.5276530056446791
# Running Train loss: 0.5274703071590782
# Running Train loss: 0.5270244346390809
# Running Train loss: 0.5265913789802598
# Running Train loss: 0.5260850840788651
# Running Train loss: 0.5257538705607349
# Running Train loss: 0.5252959977540761
# Running Train loss: 0.52516839553469
# Running Train loss: 0.5248922091816145
# Running Train loss: 0.5245514612065886
# Running Train loss: 0.5242424991747765
# Running Train loss: 0.5239135085973444
# Running Train loss: 0.5235585020456178
# Running Train loss: 0.5233427343308427
# Running Train loss: 0.522708713797531
# Running Train loss: 0.5223251602267501
# Running Train loss: 0.5221302753999526
# Running Train loss: 0.5222874377369606
# Running Train loss: 0.5224157261248836
# Running Train loss: 0.5219147875186001
# Running Train loss: 0.5212918958908648
# Running Train loss: 0.5208191561986839
# Running Train loss: 0.520449273965885
# Running Train loss: 0.5212109764174552
# Running Train loss: 0.5210914842356913
# Running Train loss: 0.5205948392200199
# Running Train loss: 0.5201044875398251
# Running Train loss: 0.5197145737322938
# Running Train loss: 0.5194844870135915
# Running Train loss: 0.5189282087851248
# Running Train loss: 0.5193459123742205
# Running Train loss: 0.5192797992398573
# Running Train loss: 0.5199889785825832
# Running Train loss: 0.5193884472953536
# Running Train loss: 0.5187859977820425
# Running Train loss: 0.5186252030510722
# Running Train loss: 0.5182642581940706
# Running Train loss: 0.5176445793897391
# Running Train loss: 0.5169142805681718
# Running Train loss: 0.5162166263610917
# Running Train loss: 0.5154971413479178
# Running Train loss: 0.5151231124200742
# Running Train loss: 0.5146644690042819
# Running Train loss: 0.5141965784755549
# Running Train loss: 0.5138242823057046
# Running Train loss: 0.5139814856903333
# Running Train loss: 0.5136515898581092
# Running Train loss: 0.513085485634661
# Running Train loss: 0.5129158937747722
# Running Train loss: 0.5126966894133737
# Running Train loss: 0.5126783439225476
# Running Train loss: 0.5123825116024818
# Running Train loss: 0.5120935563863201
# Running Train loss: 0.5118396938923475
# Running Train loss: 0.5114018153077529
# Running Train loss: 0.5117750374247031
# Running Train loss: 0.5118495674063284
# Running Train loss: 0.5115424860428852
# Running Train loss: 0.5115100787744872
# Running Train loss: 0.5111413987270518
# Running Train loss: 0.5107703168008827
# Running Train loss: 0.5104886938630263
# Running Train loss: 0.5104402877752124
# Running Train loss: 0.5102222817126332
# Running Train loss: 0.5099927395778266
# Running Train loss: 0.5096465330855069
# Running Train loss: 0.5091979527678939
# Running Train loss: 0.5088004631814673
# Running Train loss: 0.508402490881578
# Running Train loss: 0.5082425732849172
# Running Train loss: 0.5076879586335741
# Running Train loss: 0.5078676311805495
# Running Train loss: 0.5079220877663924
# Running Train loss: 0.507688665504016
# Running Train loss: 0.507362159727785
# Running Train loss: 0.5070459363702685
# Running Train loss: 0.5067716625034066
# Running Train loss: 0.5065019628082548
# Running Train loss: 0.5060022020956523
# Running Train loss: 0.5058574782443905
# Running Train loss: 0.5056871794810719
# Running Train loss: 0.505361585416785
# Running Train loss: 0.5049209425185962
# Running Train loss: 0.5045559281624217
# Running Train loss: 0.504399274697616
# Running Train loss: 0.5039599332744714
# Running Train loss: 0.5037138048535039
# Running Train loss: 0.5031732001914064
# Running Train loss: 0.5024840657433668
# Running Train loss: 0.501834024299021
# Running Train loss: 0.5011192208534576
# Running Train loss: 0.5005724340005984
# Running Train loss: 0.500146424186505
# Running Train loss: 0.4995772655492703
# Running Train loss: 0.4993680492795775
# Running Train loss: 0.49909706895930633
# Running Train loss: 0.49912865718169774
# Running Train loss: 0.49915215230795446
# Running Train loss: 0.4989102991450321
# Running Train loss: 0.49874024333444256
# Running Train loss: 0.4986540760666132
# Running Train loss: 0.4980696721728475
# Running Train loss: 0.4977263856405894
# Running Train loss: 0.49750861498545024
# Running Train loss: 0.4972775955321726
# Running Train loss: 0.49675355997409615
# Running Train loss: 0.4964296268402538
# Running Train loss: 0.49621426798933765
# Running Train loss: 0.4957254986774535
# Running Train loss: 0.4954516927767486
# Running Train loss: 0.4951506060086132
# Running Train loss: 0.4946033677595826
# Running Train loss: 0.4942000682262508
# Running Train loss: 0.4939639432309049
# Running Train loss: 0.49437137719109675
# Running Train loss: 0.49450689166842493
# Running Train loss: 0.4941855084046419
# Running Train loss: 0.4938841819954671
# Running Train loss: 0.49348128149300396
# Running Train loss: 0.4932335729143866
# Running Train loss: 0.4928593980855951
# Running Train loss: 0.4924471968980996
# Running Train loss: 0.49199637461171547
# Running Train loss: 0.4916311147318072
# Running Train loss: 0.491221579951227
# Running Train loss: 0.4908361973126347
# Running Train loss: 0.49042858454912397
# Running Train loss: 0.4900387842693806
# Running Train loss: 0.4898385698914208
# Running Train loss: 0.4893363294667288
# Running Train loss: 0.4891417099006531
# Running Train loss: 0.4887242516780999
# Running Train loss: 0.4881341430178561
# Running Train loss: 0.4880690870432913
# Running Train loss: 0.4878825998479254
# Running Train loss: 0.4875744714458106
# Running Train loss: 0.48718304499566734
# Running Train loss: 0.48711240006008627
# Running Train loss: 0.48696283452482514
# Running Train loss: 0.48675544360506695
# Running Train loss: 0.4864731841769658
# Running Train loss: 0.4863406314847392
# Running Train loss: 0.48637056491732866
# Running Train loss: 0.4860717424715752
# Running Train loss: 0.48631514987792757
# Running Train loss: 0.48655101032232617
# Running Train loss: 0.48647859286455836
# Running Train loss: 0.48621279025904923
# Running Train loss: 0.4857663737214205
# Running Train loss: 0.48539474631109736
# Running Train loss: 0.48485662931921303
# Running Train loss: 0.48419826400339516
# Running Train loss: 0.4836541413022769
# Running Train loss: 0.48352126870304346
# Running Train loss: 0.4836537210416153
# Running Train loss: 0.48388075040489
# Running Train loss: 0.483498225398854
# Running Train loss: 0.48373421004910533
# Running Train loss: 0.48335128532528965
# Running Train loss: 0.4831090468276096
# Running Train loss: 0.4826978329623485
# Running Train loss: 0.48244615393058116
# Running Train loss: 0.4822233146926852
# Running Train loss: 0.4819085849963432
# Running Train loss: 0.4815369121735734
# Running Train loss: 0.4809851524811508
# Running Train loss: 0.48062012075849536
# Running Train loss: 0.48055825233620975
# Running Train loss: 0.48039215142753994
# Running Train loss: 0.4799995928417666
# Running Train loss: 0.47980971411138557
# Running Train loss: 0.4796478291625564
# Running Train loss: 0.47900523470081335
# Running Train loss: 0.4786118590072822
# Running Train loss: 0.47834577448985865
# Running Train loss: 0.4782886509411037
# Running Train loss: 0.4779049144943541
# Running Train loss: 0.47772940539322434
# Running Train loss: 0.47754917218804277
# Running Train loss: 0.47725505907014437
# Running Train loss: 0.47697546287895515
# Running Train loss: 0.47640570163695145
# Running Train loss: 0.4760831031010419
# Running Train loss: 0.476230954522488
# Running Train loss: 0.4763138946303402
# Running Train loss: 0.4759329419661785
# Running Train loss: 0.47582449674155725
# Running Train loss: 0.4752916898709209
# Running Train loss: 0.47502661548910186
# Running Train loss: 0.4745994897830595
# Running Train loss: 0.4741818972531107
# Running Train loss: 0.4736229032616251
# Running Train loss: 0.47354129367511894
# Running Train loss: 0.4732767665125741
# Running Train loss: 0.4730937712552526
# Running Train loss: 0.472959943397695
# Running Train loss: 0.4733619510884631
# Running Train loss: 0.4732962216784625
# Running Train loss: 0.47326153297528606
# Running Train loss: 0.47301384381877865
# Running Train loss: 0.4726961337209776
# Running Train loss: 0.4728801178953741
# Running Train loss: 0.4729487150625686
# Running Train loss: 0.4730259748201326
# Running Train loss: 0.47271620304629064
# Running Train loss: 0.47250139865616003
# Running Train loss: 0.47225093426980413
# Running Train loss: 0.47185634759819656
# Running Train loss: 0.47155303575383123
# Running Train loss: 0.4712795006892865
# Running Train loss: 0.47099754582507675
# Running Train loss: 0.4708143441011603
# Running Train loss: 0.47050674539943965
# Running Train loss: 0.47057045854093016
# Running Train loss: 0.47063728073342165
# Running Train loss: 0.47060393790991323
# Running Train loss: 0.47066013568537196
# Running Train loss: 0.47047260949122055
# Running Train loss: 0.47027340530597106
# Running Train loss: 0.46989565472098527
# Running Train loss: 0.46960476586132643
# Running Train loss: 0.4692903780590633
# Running Train loss: 0.4689877001042546
# Running Train loss: 0.468812852433041
# Running Train loss: 0.4685840398316907
# Running Train loss: 0.4684202213808894
# Running Train loss: 0.46803360779865205
# Running Train loss: 0.4678467796605199
# Running Train loss: 0.46771744898165446
# Running Train loss: 0.4672695176320185
# Running Train loss: 0.4669431671130144
# Running Train loss: 0.466856271198522
# Running Train loss: 0.46670003443257574
# Running Train loss: 0.4665870608437541
# Running Train loss: 0.46631131531506265
# Running Train loss: 0.46587747948391267
# Running Train loss: 0.46554593780321535
# Running Train loss: 0.4652917980096667
# Running Train loss: 0.465116429895768
# Running Train loss: 0.46476614880204903
# Running Train loss: 0.4643028784445883
# Running Train loss: 0.46391288399472635
# Running Train loss: 0.4636496626826627
# Running Train loss: 0.4636032806811272
# Running Train loss: 0.46329986483527175
# Running Train loss: 0.4632590081421779
# Running Train loss: 0.4629497240900259
# Running Train loss: 0.4626469475487392
# Running Train loss: 0.46209568147430674
# Running Train loss: 0.46174117264118847
# Running Train loss: 0.46152382861943014
# Running Train loss: 0.46156942970887516
# Running Train loss: 0.46131812712774545
# Running Train loss: 0.46100281295546147
# Running Train loss: 0.4610225824335535
# Running Train loss: 0.4607998119882093
# Running Train loss: 0.46071500602809096
# Running Train loss: 0.46051281505523967
# Running Train loss: 0.4601032390957401
# Running Train loss: 0.4598874288150204
# Running Train loss: 0.45987471964471277
# Running Train loss: 0.45976859201978104
# Running Train loss: 0.45964010549990847
# Running Train loss: 0.4592557257102793
# Running Train loss: 0.45880388144370643
# Running Train loss: 0.45836995029704103
# Running Train loss: 0.45791686269514703
# Running Train loss: 0.45774355849411075
# Running Train loss: 0.457441256528375
# Running Train loss: 0.45724942871798724
# Running Train loss: 0.4571204654520975
# Running Train loss: 0.4569840134009157
# Running Train loss: 0.456640072706783
# Running Train loss: 0.45645070186860504
# Running Train loss: 0.45629762494248877
# Running Train loss: 0.45589253793237733
# Running Train loss: 0.45552522136356577
# Running Train loss: 0.45549265548651874
# Running Train loss: 0.4552916459725291
# Running Train loss: 0.45538083992815065
# Running Train loss: 0.4550987280743278
# Running Train loss: 0.4550100605329383
# Running Train loss: 0.45450561005931434
# Running Train loss: 0.45416471683696874
# Running Train loss: 0.4539605292234897
# Running Train loss: 0.4536464824789652
# Running Train loss: 0.4533033811093369
# Running Train loss: 0.45316227689486344
# Running Train loss: 0.4530359196005822
# Running Train loss: 0.452998848771562
# Running Train loss: 0.4528161408962465
# Running Train loss: 0.45320051881786
# Running Train loss: 0.4529555402627737
# Running Train loss: 0.45296317184785684
# Running Train loss: 0.4527481841548859
# Running Train loss: 0.452478982751235
# Running Train loss: 0.4524456322007108
# Running Train loss: 0.45230641756931866
# Running Train loss: 0.4520889974266001
# Running Train loss: 0.45184203247015264
# Running Train loss: 0.4519519960767392
# Running Train loss: 0.4517428147117213
# Running Train loss: 0.451647389276987
# Running Train loss: 0.4516083305400171
# Running Train loss: 0.45142305694268825
# Running Train loss: 0.4512506326884929
# Running Train loss: 0.450981778795377
# Running Train loss: 0.45075697946818905
# Running Train loss: 0.4510531271701636
# Running Train loss: 0.4514043283329415
# Running Train loss: 0.4512059685065896
# Running Train loss: 0.4510747452097183
# Running Train loss: 0.451073898500991
# Running Train loss: 0.4511552632348456
# Running Train loss: 0.45119317496446304
# Running Train loss: 0.45125897357107275
# Running Train loss: 0.45115397355600073
# Running Train loss: 0.4508625677280181
# Running Train loss: 0.45056998072808535
# Running Train loss: 0.4504413011580953
# Running Train loss: 0.45020601023539636
# Running Train loss: 0.45000024978952136
# Running Train loss: 0.44986494947026934
# Running Train loss: 0.4498682828721116
# Running Train loss: 0.4497761765760408
# Running Train loss: 0.44984928236945587
# Running Train loss: 0.4497183833498897
# Running Train loss: 0.44951004479648854
# Running Train loss: 0.4495350125312351
# Running Train loss: 0.4494440138963786
# Running Train loss: 0.4493386413335626
# Running Train loss: 0.4492687156193272
# Running Train loss: 0.449227159373384
# Running Train loss: 0.44900514891193116
# Running Train loss: 0.44860111329405283
# Running Train loss: 0.44820724299264164
# Running Train loss: 0.4481111920301334
# Running Train loss: 0.4482930875480555
# Running Train loss: 0.44829850483940414
# Running Train loss: 0.448214470165247
# Running Train loss: 0.44822620349597037
# Running Train loss: 0.4485952819377081
# Running Train loss: 0.44841862608052385
# Running Train loss: 0.44846327925392765
# Running Train loss: 0.44841176538724964
# Running Train loss: 0.4485717118450109
# Running Train loss: 0.4482140302568263
# Running Train loss: 0.44810293146426183
# Running Train loss: 0.44804473280829865
# Running Train loss: 0.4478430439711674
# Running Train loss: 0.4476012632484947
# Running Train loss: 0.4473165856933723
# Running Train loss: 0.4470646029981777
# Running Train loss: 0.4468750063317206
# Running Train loss: 0.44671073050552873
# Running Train loss: 0.44667509174270725
# Running Train loss: 0.44657087883997654
# Running Train loss: 0.4462904557057756
# Running Train loss: 0.44605526874645585
# Running Train loss: 0.4458054578694519
# Running Train loss: 0.4458906522052268
# Running Train loss: 0.446025554954787
# Running Train loss: 0.44569990265455095
# Running Train loss: 0.44559076668166026
# Running Train loss: 0.4455236116208396
# Running Train loss: 0.44536011146821
# Running Train loss: 0.44510469233406047
# Running Train loss: 0.44498285448863567
# Running Train loss: 0.4451150062983107
# Running Train loss: 0.44496891237336983
# Running Train loss: 0.44474107544640257
# Running Train loss: 0.4444776948720183
# Running Train loss: 0.4442214883402937
# Running Train loss: 0.44399038789988826
# Running Train loss: 0.4438302923341979
# Running Train loss: 0.4436295116920438
# Running Train loss: 0.44326766002117
# Running Train loss: 0.443057290629428
# Running Train loss: 0.4428259920584634
# Running Train loss: 0.44258849284677576
# Running Train loss: 0.44252235225674524
# Running Train loss: 0.4422425558938589
# Running Train loss: 0.4420128826610539
# Running Train loss: 0.4418880423994546
# Running Train loss: 0.44163981722452655
# Running Train loss: 0.44143723973001425
# Running Train loss: 0.441181561129595
# Running Train loss: 0.4411594286017741
# Running Train loss: 0.44106059848470663
# Running Train loss: 0.44097266768266324
# Running Train loss: 0.4408462106835484
# Running Train loss: 0.4408527857005824
# Running Train loss: 0.4405509093055256
# Running Train loss: 0.44052703827741296
# Running Train loss: 0.440531416866073
# Running Train loss: 0.44031929780081236
# Running Train loss: 0.4400499948440979
# Running Train loss: 0.4399973819589893
# Running Train loss: 0.44010119180307034
# Running Train loss: 0.4401523273466437
# Running Train loss: 0.4398962534742581
# Running Train loss: 0.4398799035557371
# Running Train loss: 0.4396331535296629
# Running Train loss: 0.43961874780783045
# Running Train loss: 0.4394370478480669
# Running Train loss: 0.4391990585813439
# Running Train loss: 0.4388358237323872
# Running Train loss: 0.43890197047276236
# Running Train loss: 0.4386719944692214
# Running Train loss: 0.43872378045210425
# Running Train loss: 0.4384834610184724
# Running Train loss: 0.4383282707586216
# Running Train loss: 0.4381269598349913
# Running Train loss: 0.43802366090982137
# Running Train loss: 0.4379348693131861
# Running Train loss: 0.43762546644367756
# Running Train loss: 0.4376332883037207
# Running Train loss: 0.4379224485822512
# Running Train loss: 0.43798029612184897
# Running Train loss: 0.4377765890380557
# Running Train loss: 0.4377453694878905
# Running Train loss: 0.4375069753639006
# Running Train loss: 0.43719779252179886
# Running Train loss: 0.43681996209421176
# Running Train loss: 0.43655863604277717
# Running Train loss: 0.436176316155807
# Running Train loss: 0.43602976928240805
# Running Train loss: 0.4357834462557739
# Running Train loss: 0.4356909329355044
# Running Train loss: 0.4356579558603637
# Running Train loss: 0.4354337680226689
# Running Train loss: 0.43513716872446395
# Running Train loss: 0.43485285586005035
# Running Train loss: 0.43461096986529413
# Running Train loss: 0.4343160889611596
# Running Train loss: 0.434197776390162
# Running Train loss: 0.43411358347226564
# Running Train loss: 0.43408270824406286
# Running Train loss: 0.4337933648393131
# Running Train loss: 0.43377761561153033
# Running Train loss: 0.433835036734148
# Running Train loss: 0.4335658385497412
# Running Train loss: 0.433625553390772
# Running Train loss: 0.4333927039006987
# Running Train loss: 0.4334593141207354
# Running Train loss: 0.4333911842580155
# Running Train loss: 0.43347865855465156
# Running Train loss: 0.43368412164679954
# Running Train loss: 0.4336942275325631
# Running Train loss: 0.43351144865116975
# Running Train loss: 0.4332671435960592
# Running Train loss: 0.4330767886083359
# Running Train loss: 0.4328090159113813
# Running Train loss: 0.4328388006603517
# Running Train loss: 0.43287418225439567
# Running Train loss: 0.4328443693700342
# Running Train loss: 0.4328369630840545
# Running Train loss: 0.432823730202092
# Running Train loss: 0.4327255349932191
# Running Train loss: 0.432518646346284
# Running Train loss: 0.43245134957059084
# Running Train loss: 0.43227890041481104
# Running Train loss: 0.4321442960073611
# Running Train loss: 0.43186700031696723
# Running Train loss: 0.4317159172810456
# Running Train loss: 0.4315178045400917
# Running Train loss: 0.4312597232749526
# Running Train loss: 0.4312131680499372
# Running Train loss: 0.4311162654257943
# Running Train loss: 0.43101393620125666
# Running Train loss: 0.43101985953074307
# Running Train loss: 0.43094664879225525
# Running Train loss: 0.4307173226260344
# Running Train loss: 0.4305942548879372
# Running Train loss: 0.43060692530069444
# Running Train loss: 0.4303485607486218
# Running Train loss: 0.43015009228635087
# Running Train loss: 0.4299085819387359
# Running Train loss: 0.4296897879429347
# Running Train loss: 0.429645515264075
# Running Train loss: 0.4295275710986473
# Running Train loss: 0.4292648345746737
# Running Train loss: 0.42909844771449296
# Running Train loss: 0.428789325906629
# Running Train loss: 0.4285324660468592
# Running Train loss: 0.4284756895984606
# Running Train loss: 0.428322794004302
# Running Train loss: 0.42813123888317717
# Running Train loss: 0.427806020921201
# Running Train loss: 0.4275430458592328
# Running Train loss: 0.42749444270332165
# Running Train loss: 0.42737251356442085
# Running Train loss: 0.42722897722972825
# Running Train loss: 0.42730825774056913
# Running Train loss: 0.4272083446833143
# Running Train loss: 0.427166510627185
# Running Train loss: 0.42693437563472525
# Running Train loss: 0.4267521059147853
# Running Train loss: 0.4265984268595018
# Running Train loss: 0.42648257598011696
# Running Train loss: 0.42638137265494686
# Running Train loss: 0.42613102897064903
# Running Train loss: 0.42602414908948577
# Running Train loss: 0.4258109595724436
# Running Train loss: 0.4256202652163449
# Running Train loss: 0.4255019331495594
# Running Train loss: 0.425288667508503
# Running Train loss: 0.4250881087320113
# Running Train loss: 0.42486419118868707
# Running Train loss: 0.42463757618505155
# Running Train loss: 0.4243659319419072
# Running Train loss: 0.42420070672148846
# Running Train loss: 0.42397411665344825
# Running Train loss: 0.42380528903327636
# Running Train loss: 0.4237277285107147
# Running Train loss: 0.4235682158426453
# Running Train loss: 0.42334426534930236
# Running Train loss: 0.4235750938785368
# Running Train loss: 0.4239069510051268
# Running Train loss: 0.4244060999699565
# Running Train loss: 0.4246416354632121
# Running Train loss: 0.4247437006425305
# Running Train loss: 0.42479450373582134
# Running Train loss: 0.4247676489913822
# Running Train loss: 0.4246928420031463
# Running Train loss: 0.42479583982023456
# Running Train loss: 0.4249074002311385
# Running Train loss: 0.4249821015520326
# Running Train loss: 0.4248333661414591
# Running Train loss: 0.4247197389542576
# Running Train loss: 0.42501899264399756
# Running Train loss: 0.4251343621501953
# Running Train loss: 0.4251793575937469
# Running Train loss: 0.42512044378702435
# Running Train loss: 0.4251259282298168
# Running Train loss: 0.4248808097357879
# Running Train loss: 0.42469701470594773
# Running Train loss: 0.4245871276754304
# Running Train loss: 0.4243827108994673
# Running Train loss: 0.4242018936464521
# Running Train loss: 0.4242133614795169
# Running Train loss: 0.4241054066933873
# Running Train loss: 0.4240155916821627
# Running Train loss: 0.42391792103501685
# Running Train loss: 0.4239738362120818
# Running Train loss: 0.42377574880233154
# Running Train loss: 0.42360358267681664
# Running Train loss: 0.42361136896139595
# Running Train loss: 0.4234273099606963
# Running Train loss: 0.4232413738574035
# Running Train loss: 0.42309814159780046
# Running Train loss: 0.42284086147724864
# Running Train loss: 0.4226174464876467
# Running Train loss: 0.4224566132960243
# Running Train loss: 0.42224317060419264
# Running Train loss: 0.4220748696941882
# Running Train loss: 0.42192874765273436
# Running Train loss: 0.4216169996889456
# Running Train loss: 0.4215389379693173
# Running Train loss: 0.4212662215736382
# Running Train loss: 0.4210410438563829
# Running Train loss: 0.42111851817466883
# Running Train loss: 0.4209662996002892
# Running Train loss: 0.42110294754692246
# Running Train loss: 0.42092874022739485
# Running Train loss: 0.42088223234194955
# Running Train loss: 0.4206963474106805
# Running Train loss: 0.4205803311184294
# Running Train loss: 0.420546493454677
# Running Train loss: 0.42048535546904237
# Running Train loss: 0.42038744832793057
# Running Train loss: 0.4203398545344027
# Running Train loss: 0.4201833302496424
# Running Train loss: 0.42040441063604234
# Running Train loss: 0.4204295263951941
# Running Train loss: 0.42042170526459816
# Running Train loss: 0.42018800855298727
# Running Train loss: 0.4199148131595306
# Running Train loss: 0.41981315476176473
# Running Train loss: 0.41966371509361255
# Running Train loss: 0.41955347666474757
# Running Train loss: 0.4192357499061479
# Running Train loss: 0.4190682537749396
# Running Train loss: 0.41894782672632846
# Running Train loss: 0.4187360199183441
# Running Train loss: 0.41852809806094243
# Running Train loss: 0.41857207125064544
# Running Train loss: 0.4183217094283176
# Running Train loss: 0.41816262009671595
# Running Train loss: 0.41805299232869375
# Running Train loss: 0.4179490381743208
# Running Train loss: 0.41777702262558336
# Running Train loss: 0.4176838229007639
# Running Train loss: 0.4175987447493698
# Running Train loss: 0.4175565549229888
# Running Train loss: 0.41753507386061495
# Running Train loss: 0.4174451339810449
# Running Train loss: 0.4173435297530682
# Running Train loss: 0.4173795240827548
# Running Train loss: 0.4171839134015302
# Running Train loss: 0.41702228096293076
# Running Train loss: 0.41693841339606746
# Running Train loss: 0.41691759882367546
# Running Train loss: 0.41685482387179973
# Running Train loss: 0.4166619711736196
# Running Train loss: 0.41649013512924443
# Running Train loss: 0.4164425008226216
# Running Train loss: 0.4163125145558413
# Running Train loss: 0.41626677638296256
# Running Train loss: 0.41604894155725125
# Running Train loss: 0.41585178138105616
# Running Train loss: 0.41567261446706794
# Running Train loss: 0.4154849368456355
# Running Train loss: 0.41525274260306766
# Running Train loss: 0.41506031589113224
# Running Train loss: 0.41497420016839576
# Running Train loss: 0.4149399620385336
# Running Train loss: 0.41479132692908605
# Running Train loss: 0.4145596621122964
# Running Train loss: 0.41429687894301137
# Running Train loss: 0.4142807961144692
# Running Train loss: 0.41409918761943804
# Running Train loss: 0.41384429330495043
# Running Train loss: 0.4136768392423486
# Running Train loss: 0.41341163248984425
# Running Train loss: 0.41349518077367026
# Running Train loss: 0.41324140750790916
# Running Train loss: 0.4130670647702775
# Running Train loss: 0.41297115961126885
# Running Train loss: 0.4127132074513587
# Running Train loss: 0.4124871702856703
# Running Train loss: 0.412215830769493
# Running Train loss: 0.41217278843534694
# Running Train loss: 0.41202252237721376
# Running Train loss: 0.4117397456393739
# Running Train loss: 0.4115545252000849
# Running Train loss: 0.411311204977571
# Running Train loss: 0.41097282213856196
# Running Train loss: 0.41078843863926
# Running Train loss: 0.4106325471911362
# Running Train loss: 0.41065610381954476
# Running Train loss: 0.41064091050585233
# Running Train loss: 0.4105299237585645
# Running Train loss: 0.4105661167294323
# Running Train loss: 0.41047605008709065
# Running Train loss: 0.4104455503722669
# Running Train loss: 0.4104019116966593
# Running Train loss: 0.4104735117243546
# Running Train loss: 0.41042243510338605
# Running Train loss: 0.4103396537791449
# Running Train loss: 0.4103321725589798
# Running Train loss: 0.4106568003114516
# Running Train loss: 0.4109487720261136
# Running Train loss: 0.41087510600742994
# Running Train loss: 0.411021440243309
# Running Train loss: 0.4108437162413562
# Running Train loss: 0.4106388455501282
# Running Train loss: 0.41072236882229596
# Running Train loss: 0.4106436595336447
# Running Train loss: 0.4107303362468736
# Running Train loss: 0.4107783068663083
# Running Train loss: 0.4107176481399051
# Running Train loss: 0.41062441705031716
# Running Train loss: 0.4105300614908212
# Running Train loss: 0.41039088008262664
# Running Train loss: 0.4103495008633042
# Running Train loss: 0.41049136651334245
# Running Train loss: 0.41050446949330405
# Running Train loss: 0.41040795028041066
# Running Train loss: 0.41062997818972846
# Running Train loss: 0.4105901768594731
# Running Train loss: 0.4104929171754888
# Running Train loss: 0.4104829532737745
# Running Train loss: 0.4107902910830904
# Running Train loss: 0.411136819043502
# Running Train loss: 0.411538710949632
# Running Train loss: 0.4113718139195348
# Running Train loss: 0.4111794343608712
# Running Train loss: 0.41137957049755136
# Running Train loss: 0.41134904223057966
# Running Train loss: 0.4112990947386165
# Running Train loss: 0.411252023687719
# Running Train loss: 0.4113832199290185
# Running Train loss: 0.4112165907215919
# Running Train loss: 0.4111095040472728
# Running Train loss: 0.41105061214848243
# Running Train loss: 0.4109204768546965
# Running Train loss: 0.4109059245380951
# Running Train loss: 0.4108228065512663
# Running Train loss: 0.410737833381006
# Running Train loss: 0.41065067231440494
# Running Train loss: 0.4107861537685446
# Running Train loss: 0.4107055587612931
# Running Train loss: 0.4105311029212938
# Running Train loss: 0.4105965006833711
# Running Train loss: 0.4105808544308558
# Running Train loss: 0.4105561543011963
# Running Train loss: 0.4103796947122523
# Running Train loss: 0.4104900713644477
# Running Train loss: 0.4104587941634426
# Running Train loss: 0.410439765959674
# Running Train loss: 0.4103451727511176
# Running Train loss: 0.4102962335682464
# ...
# Running Train loss: 0.12657231606253408
# Running Train loss: 0.12657541332558508
# Running Train loss: 0.12656759335291445
# Running Train loss: 0.1265427935439901
# Running Train loss: 0.12656186792491153
# Running Train loss: 0.12658396842496727
# Running Train loss: 0.1265772202202125
# Running Train loss: 0.12669032482500894
# Running Train loss: 0.12679529210836313
# Running Train loss: 0.12679575405325447
# Running Train loss: 0.12680028382583403
# Running Train loss: 0.1267872124353194
# Running Train loss: 0.12680817367101027
# Running Train loss: 0.12685803925083694
# Running Train loss: 0.12689426961308822
# Running Train loss: 0.12693525777988707
# Running Train loss: 0.1268976158303876
# Running Train loss: 0.126879531158701
# Running Train loss: 0.12687300422401568
# Running Train loss: 0.12682790242857833
# Running Train loss: 0.126799695422398
# Running Train loss: 0.12675656896107496
# Running Train loss: 0.12682058855278736
# Running Train loss: 0.12678939218357282
# Running Train loss: 0.12679625359105742
# Running Train loss: 0.12677405722122706
# Running Train loss: 0.12671506199207316
# Running Train loss: 0.12668108047964888
# Running Train loss: 0.12663959794848342
# Running Train loss: 0.12663564175653103
# Running Train loss: 0.1266454561791359
# Running Train loss: 0.1266391761390951
# Running Train loss: 0.12660225920837873
# Running Train loss: 0.1266380511770227
# Running Train loss: 0.12668068516962275
# Running Train loss: 0.12667430326005685
# Running Train loss: 0.12666770533304672
# Running Train loss: 0.12666013480865373
# Running Train loss: 0.12666122699231197
# Running Train loss: 0.1266472248481498
# Running Train loss: 0.12661230504035229
# Running Train loss: 0.12658221366764943
# Running Train loss: 0.1265528952433432
# Running Train loss: 0.12658843331048342
# Running Train loss: 0.126562012624626
# Running Train loss: 0.12650697411193018
# Running Train loss: 0.12645798908475436
# Running Train loss: 0.12643194414755143
# Running Train loss: 0.12641573609332077
# Running Train loss: 0.1263714264914554
# Running Train loss: 0.12632442371272282
# Running Train loss: 0.12625867827702533
# Running Train loss: 0.12622319671358354
# Running Train loss: 0.12618855110225202
# Running Train loss: 0.1261703309834357
# Running Train loss: 0.12612970938834223
# Running Train loss: 0.1260775059239315
# Running Train loss: 0.12607789557002594
# Running Train loss: 0.12604838086066025
# Running Train loss: 0.12598551622004775
# Running Train loss: 0.1260304986005698
# Running Train loss: 0.12601637187047135
# Running Train loss: 0.12605354234458785
# Running Train loss: 0.12601364312700575
# Running Train loss: 0.12607080526947298
# Running Train loss: 0.12610073837375843
# Running Train loss: 0.1261443081457656
# Running Train loss: 0.12614391335022054
# Running Train loss: 0.12608714585822817
# Running Train loss: 0.12615335299581765
# Running Train loss: 0.12612420831474225
# Running Train loss: 0.12611837426807446
# Running Train loss: 0.12611607429489993
# Running Train loss: 0.12609739738284764
# Running Train loss: 0.12616179868197594
# Running Train loss: 0.1261327729504328
# Running Train loss: 0.12624556597589323
# Running Train loss: 0.1262392981964716
# Running Train loss: 0.12626956881972043
# Running Train loss: 0.12630617109646006
# Running Train loss: 0.12633990023668382
# Running Train loss: 0.12634306503775833
# Running Train loss: 0.1263618456012151
# Running Train loss: 0.12629286435296216
# Running Train loss: 0.12629953147366224
# Running Train loss: 0.1262726890575626
# Running Train loss: 0.1262182748240638
# Running Train loss: 0.1261645267745803
# Running Train loss: 0.1261182668206461
# Running Train loss: 0.12617870048777358
# Running Train loss: 0.1261642710540865
# Running Train loss: 0.12621539152501798
# Running Train loss: 0.12620418286689097
# Running Train loss: 0.1261770717590706
# Running Train loss: 0.12613779618688975
# Running Train loss: 0.12615128862068714
# Running Train loss: 0.12614235803369772
# Running Train loss: 0.12611633006967712
# Running Train loss: 0.1260939494786663
# Running Train loss: 0.12607775172221353
# Running Train loss: 0.1261301347778814
# Running Train loss: 0.12612585047563782
# Running Train loss: 0.12610643801097904
# Running Train loss: 0.12610453598530386
# Running Train loss: 0.12609085635549713
# Running Train loss: 0.12606120702037502
# Running Train loss: 0.12600374615643645
# Running Train loss: 0.1259809884238722
# Running Train loss: 0.1259898371604361
# Running Train loss: 0.1259665036698661
# Running Train loss: 0.12607115675234096
# Running Train loss: 0.12608067310527243
# Running Train loss: 0.12605087156619801
# Running Train loss: 0.12603072925422507
# Running Train loss: 0.12604197596653546
# Running Train loss: 0.12603480027910677
# Running Train loss: 0.12602106241004743
# Running Train loss: 0.12604641779127468
# Running Train loss: 0.12604340679284073
# Running Train loss: 0.12608554489314916
# Running Train loss: 0.12605685877858835
# Running Train loss: 0.12604056040889977
# Running Train loss: 0.1260084793289527
# Running Train loss: 0.12597816236465348
# Running Train loss: 0.12593259887775615
# Running Train loss: 0.1259445221864195
# Running Train loss: 0.12599891995936907
# Running Train loss: 0.1260321198695597
# Running Train loss: 0.12603019782681732
# Running Train loss: 0.12599845676912566
# Running Train loss: 0.1259479670772498
# Running Train loss: 0.12599425518262097
# Running Train loss: 0.12598300909295573
# Running Train loss: 0.1259722346881759
# Running Train loss: 0.12594647532615644
# Running Train loss: 0.1260009827606927
# Running Train loss: 0.12595614481012182
# Running Train loss: 0.12595850115424817
# Running Train loss: 0.1259962941894066
# Running Train loss: 0.12598937384872547
# Running Train loss: 0.1259804209648562
# Running Train loss: 0.12592947986950542
# Running Train loss: 0.12591752771624684
# Running Train loss: 0.1258834928571646
# Running Train loss: 0.12582235806282854
# Running Train loss: 0.12582956801204562
# Running Train loss: 0.1258324107407426
# Running Train loss: 0.12580020664137523
# Running Train loss: 0.12576902835808762
# Running Train loss: 0.12571674318847467
# Running Train loss: 0.12569572100490103
# Running Train loss: 0.12567521332710704
# Running Train loss: 0.12572583478984414
# Running Train loss: 0.125701274229281
# Running Train loss: 0.12567840546846876
# Running Train loss: 0.12568850311006755
# Running Train loss: 0.12567837128408973
# Running Train loss: 0.1256485212554172
# Running Train loss: 0.12570982411524995
# Running Train loss: 0.12575095764205757
# Running Train loss: 0.12568364944786797
# Running Train loss: 0.1257804998181432
# Running Train loss: 0.12573363313005098
# Running Train loss: 0.1256968610553104
# Running Train loss: 0.12568893956624005
# Running Train loss: 0.12579952151243126
# Running Train loss: 0.12578500145539176
# Running Train loss: 0.12575320799163547
# Running Train loss: 0.12571944307172306
# Running Train loss: 0.1256677823802446
# Running Train loss: 0.12563079561777743
# Running Train loss: 0.1256629195724806
# Running Train loss: 0.12562874622409523
# Running Train loss: 0.1255839213449149
# Running Train loss: 0.12557658769539365
# Running Train loss: 0.12555111817950515
# Running Train loss: 0.12549307325958833
# Running Train loss: 0.1254404472853671
# Running Train loss: 0.12544091815783048
# Running Train loss: 0.12540147278437944
# Running Train loss: 0.12543054802833178
# Running Train loss: 0.1254576928414488
# Running Train loss: 0.12545139218757106
# Running Train loss: 0.12554548585214648
# Running Train loss: 0.1255772080922119
# Running Train loss: 0.1255783443890677
# Running Train loss: 0.12558322997359958
# Running Train loss: 0.1255938801030206
# Running Train loss: 0.1256238789757198
# Running Train loss: 0.12560287779148802
# Running Train loss: 0.1256521155005214
# Running Train loss: 0.12560172222725816
# Running Train loss: 0.12560167634715033
# Running Train loss: 0.12557591171339175
# Running Train loss: 0.12559954988872596
# Running Train loss: 0.12554378387094114
# Running Train loss: 0.12556753103300228
# Running Train loss: 0.12553418896112936
# Running Train loss: 0.12553616277157698
# Running Train loss: 0.1255542476340192
# Running Train loss: 0.12554222859082945
# Running Train loss: 0.12553389748538704
# Running Train loss: 0.125505554840741
# Running Train loss: 0.12544377324641062
# Running Train loss: 0.12546047783440606
# Running Train loss: 0.12563996109418527
# Running Train loss: 0.12561902081180343
# Running Train loss: 0.1255771296361864
# Running Train loss: 0.12559629589843005
# Running Train loss: 0.12571772859297536
# Running Train loss: 0.1257861475524313
# Running Train loss: 0.12574478414348209
# Running Train loss: 0.12578408671831687
# Running Train loss: 0.12576797295370287
# Running Train loss: 0.12575858410041102
# Running Train loss: 0.1257377651233609
# Running Train loss: 0.12570669731180845
# Running Train loss: 0.12587925468393732
# Running Train loss: 0.12583453840679204
# Running Train loss: 0.125813813525088
# Running Train loss: 0.1258054857427965
# Running Train loss: 0.1257498250324169
# Running Train loss: 0.12574496633577942
# Running Train loss: 0.1256798320250997
# Running Train loss: 0.12569539282203068
# Running Train loss: 0.12573576098488948
# Running Train loss: 0.12573286156028554
# Running Train loss: 0.12570684947170577
# Running Train loss: 0.12565398724803942
# Running Train loss: 0.12561711285133453
# Running Train loss: 0.12558807115850187
# Running Train loss: 0.1255842011242761
# Running Train loss: 0.12568534747995436
# Running Train loss: 0.12566154800305293
# Running Train loss: 0.1256392356795971
# Running Train loss: 0.12564842047304198
# Running Train loss: 0.12562229761721477
# Running Train loss: 0.12562469588233494
# Running Train loss: 0.12560674766633623
# Running Train loss: 0.12560042412939218
# Running Train loss: 0.1256050690834223
# Running Train loss: 0.12559229401896774
# Running Train loss: 0.12555906561386107
# Running Train loss: 0.12549493854264468
# Running Train loss: 0.12550309308060303
# Running Train loss: 0.1254807538800563
# Running Train loss: 0.12550404169838314
# Running Train loss: 0.1254683177714931
# Running Train loss: 0.12546718200298823
# Running Train loss: 0.12548279103192445
# Running Train loss: 0.12546979278713224
# Running Train loss: 0.1254398032265382
# Running Train loss: 0.125459663701025
# Running Train loss: 0.1254457258495339
# Running Train loss: 0.1254134450708484
# Running Train loss: 0.12540001430545292
# Running Train loss: 0.12538824083046668
# Running Train loss: 0.12538134332684997
# Running Train loss: 0.12533516376984769
# Running Train loss: 0.12534694833625656
# Running Train loss: 0.12532346401374866
# Running Train loss: 0.12529988102201556
# Running Train loss: 0.1253718131223053
# Running Train loss: 0.12542849632675376
# Running Train loss: 0.1254799825508796
# Running Train loss: 0.1254326387769074
# Running Train loss: 0.12544120375285067
# Running Train loss: 0.12544116797693639
# Running Train loss: 0.12541393211030039
# Running Train loss: 0.12544138769842741
# Running Train loss: 0.12547200353988006
# Running Train loss: 0.1254225300099212
# Running Train loss: 0.12541196978646124
# Running Train loss: 0.12543147627887896
# Running Train loss: 0.125408232228949
# Running Train loss: 0.1253620441258876
# Running Train loss: 0.12535784337773953
# Running Train loss: 0.12534774790340938
# Running Train loss: 0.1254311136639338
# Running Train loss: 0.1254297800290153
# Running Train loss: 0.12541281924877476
# Running Train loss: 0.12543345814057202
# Running Train loss: 0.12542459598742425
# Running Train loss: 0.12542010822997313
# Running Train loss: 0.1254277792194985
# Running Train loss: 0.12541370371419885
# Running Train loss: 0.1253751985154932
# Running Train loss: 0.12533281772998234
# Running Train loss: 0.12531140075616948
# Running Train loss: 0.12531900218594916
# Running Train loss: 0.12530712280082779
# Running Train loss: 0.12527792492191353
# Running Train loss: 0.12526076547837592
# Running Train loss: 0.12529995816715028
# Running Train loss: 0.12534767029401653
# Running Train loss: 0.1253408649863033
# Running Train loss: 0.1253654166047191
# Running Train loss: 0.1253466458985169
# Running Train loss: 0.12539618769154387
# Running Train loss: 0.12537511374192825
# Running Train loss: 0.12533749603116104
# Running Train loss: 0.12535139551104063
# Running Train loss: 0.12534978113491518
# Running Train loss: 0.12530654396147267
# Running Train loss: 0.12527934517642042
# Running Train loss: 0.12538728191700402
# Running Train loss: 0.12539074540827777
# Running Train loss: 0.125353453345955
# Running Train loss: 0.1253395876256479
# Running Train loss: 0.1253086925081319
# Running Train loss: 0.125342752457717
# Running Train loss: 0.1253384693902026
# Running Train loss: 0.12532845364676318
# Running Train loss: 0.1253263175077803
# Running Train loss: 0.1253321251626601
# Running Train loss: 0.1253153172575377
# Running Train loss: 0.12530314707769638
# Running Train loss: 0.12530730682156732
# Running Train loss: 0.12526762674843786
# Running Train loss: 0.1252975702511477
# Running Train loss: 0.1252851784356191
# Running Train loss: 0.12532741280285406
# Running Train loss: 0.12530346421167046
# Running Train loss: 0.12534384960903183
# Running Train loss: 0.12532817934219306
# Running Train loss: 0.12531333935493888
# Running Train loss: 0.12530801272828088
# Running Train loss: 0.12527408670329107
# Running Train loss: 0.12526759505401852
# Running Train loss: 0.125238007275859
# Running Train loss: 0.12518421410548974
# Running Train loss: 0.12522229753005798
# Running Train loss: 0.12519138951785863
# Running Train loss: 0.1251961214514779
# Running Train loss: 0.12524550721239153
# Running Train loss: 0.12523276552770293
# Running Train loss: 0.12518916584533923
# Running Train loss: 0.12515880345599725
# Running Train loss: 0.12512884480967565
# Running Train loss: 0.1251605768277104
# Running Train loss: 0.12510226637609229
# Running Train loss: 0.12511582110786432
# Running Train loss: 0.12509442278047933
# Running Train loss: 0.12504565631930903
# Running Train loss: 0.12503623925081478
# Running Train loss: 0.12499244090427797
# Running Train loss: 0.12498505957236877
# Running Train loss: 0.12494946779044411
# Running Train loss: 0.12490172339437249
# Running Train loss: 0.1248518719503153
# Running Train loss: 0.12485957996813675
# Running Train loss: 0.12483152544530858
# Running Train loss: 0.12478815818982746
# Running Train loss: 0.12472910035127692
# Running Train loss: 0.12471966175854478
# Running Train loss: 0.12474122077184222
# Running Train loss: 0.12476584026596978
# Running Train loss: 0.12477693792956415
# Running Train loss: 0.12472403260366316
# Running Train loss: 0.1246828953197066
# Running Train loss: 0.12463962465221982
# Running Train loss: 0.12462448110460525
# Running Train loss: 0.12459565254632021
# Running Train loss: 0.12456975568233082
# Running Train loss: 0.1245456077507639
# Running Train loss: 0.12450186863499396
# Running Train loss: 0.12448726716982604
# Running Train loss: 0.12447655665194755
# Running Train loss: 0.12447575601788023
# Running Train loss: 0.1244560515756393
# Running Train loss: 0.12443775175612604
# Running Train loss: 0.12442126646492253
# Running Train loss: 0.12439988363249962
# Running Train loss: 0.12438141867402472
# Running Train loss: 0.1243630777736253
# Running Train loss: 0.12442727577981029
# Running Train loss: 0.12444522273297771
# Running Train loss: 0.12443135343641873
# Running Train loss: 0.12443781361126242
# Running Train loss: 0.12444952074090584
# Running Train loss: 0.12442322666627906
# Running Train loss: 0.1243968316932023
# Running Train loss: 0.12438807901926338
# Running Train loss: 0.1243515947052422
# Running Train loss: 0.12434465235379925
# Running Train loss: 0.12434107206426138
# Running Train loss: 0.12441751710621171
# Running Train loss: 0.1243874234166868
# Running Train loss: 0.12441038089191724
# Running Train loss: 0.1245270368372004
# Running Train loss: 0.12451503729066123
# Running Train loss: 0.12448015217447238
# Running Train loss: 0.12447778623910387
# Running Train loss: 0.12450068559251042
# Running Train loss: 0.12453262612123497
# Running Train loss: 0.12453896577515246
# Running Train loss: 0.12452520570734195
# Running Train loss: 0.12448949168091548
# Running Train loss: 0.1244671923277917
# Running Train loss: 0.12443095036765449
# Running Train loss: 0.1244156192702105
# Running Train loss: 0.12437241245391496
# Running Train loss: 0.1243585947396639

# %%
tagger.model.eval()

# Only get 87% after 2 epochs and 85% after 1 epoch :(. Might be overfit somewhere between 1 and 2.
# 0.54 running loss after 1 epoch
# 0.12 running loss after 1 epoch
print(tagger.predict(["the","cat", "sat","on","the","floor"]))
print('{:.4f}'.format(accuracy(tagger, dev_data)))
# Out:
# ['DET', 'NOUN', 'VERB', 'ADP', 'DET', 'NOUN']
# 0.8709

# %%
# Still only get 87% accuracy, but after 1 epoch
# 0.35 running loss after 1 epoch. Faster than without pretrained.
tagger_glove = train_fixed_window(train_data)
print('{:.4f}'.format(accuracy(tagger_glove, dev_data)))
# Out:
# Running Train loss: 2.884531021118164
# Running Train loss: 2.855155348777771
# Running Train loss: 2.835790236790975
# Running Train loss: 2.8074735403060913
# Running Train loss: 2.7792219161987304
# Running Train loss: 2.754789153734843
# Running Train loss: 2.7260379450661794
# Running Train loss: 2.6965775191783905
# Running Train loss: 2.6606605052948
# Running Train loss: 2.62369019985199
# Running Train loss: 2.6128385717218574
# Running Train loss: 2.578044831752777
# Running Train loss: 2.556109171647292
# Running Train loss: 2.5198684419904436
# Running Train loss: 2.483534407615662
# Running Train loss: 2.439778581261635
# Running Train loss: 2.408045705626993
# Running Train loss: 2.367085145579444
# Running Train loss: 2.3283256543310067
# Running Train loss: 2.2924031376838685
# Running Train loss: 2.2493217899685813
# Running Train loss: 2.1956015175039116
# Running Train loss: 2.1607622270998745
# Running Train loss: 2.2166581749916077
# Running Train loss: 2.1782217741012575
# Running Train loss: 2.145544088803805
# Running Train loss: 2.1184770310366594
# Running Train loss: 2.088374129363469
# Running Train loss: 2.051115969131733
# Running Train loss: 2.017529916763306
# Running Train loss: 1.9864484071731567
# Running Train loss: 1.9698197916150093
# Running Train loss: 1.9424829121791956
# Running Train loss: 1.9171923574279337
# Running Train loss: 1.8970392942428589
# Running Train loss: 1.8788642916414473
# Running Train loss: 1.8609228391905088
# Running Train loss: 1.8382261160172915
# Running Train loss: 1.8136882751415937
# Running Train loss: 1.790413472056389
# Running Train loss: 1.7719732057757493
# Running Train loss: 1.7485042001519884
# Running Train loss: 1.729741978090863
# Running Train loss: 1.7161764421246268
# Running Train loss: 1.6986870500776503
# Running Train loss: 1.6781870152639307
# Running Train loss: 1.6555859294343502
# Running Train loss: 1.634706584115823
# Running Train loss: 1.6114854265232474
# Running Train loss: 1.5916266107559205
# Running Train loss: 1.5757127883387547
# Running Train loss: 1.5574303292311156
# Running Train loss: 1.541466570125436
# Running Train loss: 1.5226755495424624
# Running Train loss: 1.5075687224214727
# Running Train loss: 1.495315996663911
# Running Train loss: 1.4810680150985718
# Running Train loss: 1.466816619552415
# Running Train loss: 1.456265030270916
# Running Train loss: 1.4441265016794205
# Running Train loss: 1.431030933974219
# Running Train loss: 1.41590563616445
# Running Train loss: 1.4002067512936063
# Running Train loss: 1.3875193670392036
# Running Train loss: 1.3692308290646626
# Running Train loss: 1.3555225312258259
# Running Train loss: 1.342059619168737
# Running Train loss: 1.3317468120333027
# Running Train loss: 1.3247007906868837
# Running Train loss: 1.3125130957790783
# Running Train loss: 1.2997842643042685
# Running Train loss: 1.2891640300965972
# Running Train loss: 1.2789896891949928
# Running Train loss: 1.267214633927152
# Running Train loss: 1.2573842801650366
# Running Train loss: 1.246659094761861
# Running Train loss: 1.2363017919388684
# Running Train loss: 1.2265696130119836
# Running Train loss: 1.216653049558024
# Running Train loss: 1.2078826455399394
# Running Train loss: 1.2005882739652822
# Running Train loss: 1.194478868529564
# Running Train loss: 1.1863189194216786
# Running Train loss: 1.1855260025532472
# Running Train loss: 1.1814198323908973
# Running Train loss: 1.1731179403357728
# Running Train loss: 1.1803873974358898
# Running Train loss: 1.1784926630895247
# Running Train loss: 1.1705907903025659
# Running Train loss: 1.164874363442262
# Running Train loss: 1.1610413388564036
# Running Train loss: 1.1559055912429872
# Running Train loss: 1.14966234773077
# Running Train loss: 1.1428914353885549
# Running Train loss: 1.134074240452365
# Running Train loss: 1.129315931815654
# Running Train loss: 1.1238603111087662
# Running Train loss: 1.117984773401095
# Running Train loss: 1.1142754288333836
# Running Train loss: 1.10948622033
# Running Train loss: 1.1039087298778023
# Running Train loss: 1.098431187371413
# Running Train loss: 1.0920570306118251
# Running Train loss: 1.0864128526300192
# Running Train loss: 1.0802961240212123
# Running Train loss: 1.0733580953388844
# Running Train loss: 1.065834275333681
# Running Train loss: 1.0582286416104547
# Running Train loss: 1.0544675882529775
# Running Train loss: 1.0486182712695815
# Running Train loss: 1.0434733541967633
# Running Train loss: 1.0379965101767863
# Running Train loss: 1.0326816000505887
# Running Train loss: 1.0279121876024364
# Running Train loss: 1.023133122532264
# Running Train loss: 1.0203044302761555
# Running Train loss: 1.0158965033598435
# Running Train loss: 1.0110688561857757
# Running Train loss: 1.0093366787964557
# Running Train loss: 1.0055829747269551
# Running Train loss: 1.0008952966160025
# Running Train loss: 0.9960720953149874
# Running Train loss: 0.993618207612658
# Running Train loss: 0.9947824212572267
# Running Train loss: 0.9964454206228256
# Running Train loss: 0.9932726511643046
# Running Train loss: 0.9874168447856828
# Running Train loss: 0.9827865193365142
# Running Train loss: 0.9783346337634463
# Running Train loss: 0.9735503216202442
# Running Train loss: 0.9687813216720829
# Running Train loss: 0.9651319911759911
# Running Train loss: 0.962597541679117
# Running Train loss: 0.9572614767213365
# Running Train loss: 0.9543171244638937
# Running Train loss: 0.9492503514184671
# Running Train loss: 0.9465547721751415
# Running Train loss: 0.9435996668062349
# Running Train loss: 0.9408947679636289
# Running Train loss: 0.9376907678587096
# Running Train loss: 0.9339554043526345
# Running Train loss: 0.9312842958410021
# Running Train loss: 0.9269019011017325
# Running Train loss: 0.923907820135355
# Running Train loss: 0.9217273173661068
# Running Train loss: 0.9191336729755141
# Running Train loss: 0.9157057445065505
# Running Train loss: 0.9129832556118836
# Running Train loss: 0.9085837172581845
# Running Train loss: 0.9049725327889124
# Running Train loss: 0.9023006694601071
# Running Train loss: 0.8978573369156373
# Running Train loss: 0.894153005254814
# Running Train loss: 0.8907136207857689
# Running Train loss: 0.8871801879136793
# Running Train loss: 0.8823410303164752
# Running Train loss: 0.878276949000966
# Running Train loss: 0.8764183278891104
# Running Train loss: 0.8729833931480564
# Running Train loss: 0.8703118671663106
# Running Train loss: 0.8660789582855213
# Running Train loss: 0.86379526288789
# Running Train loss: 0.8611845270804832
# Running Train loss: 0.8582384383714781
# Running Train loss: 0.8544540033195958
# Running Train loss: 0.8518879047359329
# Running Train loss: 0.8490457686478506
# Running Train loss: 0.8462386475432486
# Running Train loss: 0.84314911834587
# Running Train loss: 0.8415275372126523
# Running Train loss: 0.839745251930248
# Running Train loss: 0.8368721344443255
# Running Train loss: 0.835397673824619
# Running Train loss: 0.8330980588992437
# Running Train loss: 0.8314958376543863
# Running Train loss: 0.8286301849240606
# Running Train loss: 0.8255355299192634
# Running Train loss: 0.8219750142666731
# Running Train loss: 0.8199816593411249
# Running Train loss: 0.8179513620833556
# Running Train loss: 0.8159677564933155
# Running Train loss: 0.8137627950572706
# Running Train loss: 0.8127346200858309
# Running Train loss: 0.810157447486468
# Running Train loss: 0.8085887381353893
# Running Train loss: 0.8057355852697485
# Running Train loss: 0.8038858212729826
# Running Train loss: 0.8022351742900432
# Running Train loss: 0.801694959165558
# Running Train loss: 0.8012916950018782
# Running Train loss: 0.7991478459529228
# Running Train loss: 0.7974021311383694
# Running Train loss: 0.7971314600249029
# Running Train loss: 0.7962250716446602
# Running Train loss: 0.7951986622351866
# Running Train loss: 0.7928912058016475
# Running Train loss: 0.7905166568943691
# Running Train loss: 0.7915913362545196
# Running Train loss: 0.7902135012587111
# Running Train loss: 0.7880533849447966
# Running Train loss: 0.7859308204395854
# Running Train loss: 0.7854401399150933
# Running Train loss: 0.7836939925190263
# Running Train loss: 0.7820327428772169
# Running Train loss: 0.7811001702779676
# Running Train loss: 0.7794721107025748
# Running Train loss: 0.7777771158638783
# Running Train loss: 0.7765055818196672
# Running Train loss: 0.7763865944443707
# Running Train loss: 0.7747446673966589
# Running Train loss: 0.7757222540146932
# Running Train loss: 0.7742487067743292
# Running Train loss: 0.7739623588435527
# Running Train loss: 0.7728241778840529
# Running Train loss: 0.7709715279728867
# Running Train loss: 0.7686105311882717
# Running Train loss: 0.7660765182312732
# Running Train loss: 0.7639327593352816
# Running Train loss: 0.7628645785323017
# Running Train loss: 0.760566418143836
# Running Train loss: 0.7590195307364831
# Running Train loss: 0.7574292944895255
# Running Train loss: 0.7569250178444011
# Running Train loss: 0.756015175155231
# Running Train loss: 0.7559759502940707
# Running Train loss: 0.7542524857331167
# Running Train loss: 0.7527414194025132
# Running Train loss: 0.7520543312033018
# Running Train loss: 0.7522934775425357
# Running Train loss: 0.7507780292759771
# Running Train loss: 0.7494763814525687
# Running Train loss: 0.7471490149097196
# Running Train loss: 0.7464060761642046
# Running Train loss: 0.7446274126951511
# Running Train loss: 0.7433510453143019
# Running Train loss: 0.7418208248534445
# Running Train loss: 0.7405838932417617
# Running Train loss: 0.7380940189131168
# Running Train loss: 0.7362724656091075
# Running Train loss: 0.7349116610984008
# Running Train loss: 0.7333905848972035
# Running Train loss: 0.732090370837322
# Running Train loss: 0.7322392089622011
# Running Train loss: 0.7302375140248752
# Running Train loss: 0.7278007256741427
# Running Train loss: 0.7261633217577043
# Running Train loss: 0.7244578169183693
# Running Train loss: 0.7233991912536083
# Running Train loss: 0.7221254636963688
# Running Train loss: 0.7205578166246415
# Running Train loss: 0.718418519691642
# Running Train loss: 0.7173332484468581
# Running Train loss: 0.7151281774750812
# Running Train loss: 0.7139660836908761
# Running Train loss: 0.712289723929237
# Running Train loss: 0.7104554870747961
# Running Train loss: 0.7083273790341871
# Running Train loss: 0.7068780603450399
# Running Train loss: 0.7049038105834865
# Running Train loss: 0.7031818024814129
# Running Train loss: 0.7012916840470157
# Running Train loss: 0.6997448151916948
# Running Train loss: 0.6982555311782278
# Running Train loss: 0.6968018156899647
# Running Train loss: 0.6947256257511535
# Running Train loss: 0.6929678172993481
# Running Train loss: 0.6916336968596954
# Running Train loss: 0.6904206300404534
# Running Train loss: 0.6884868368229459
# Running Train loss: 0.6868056136700842
# Running Train loss: 0.6851775217870065
# Running Train loss: 0.683678539305487
# Running Train loss: 0.6823865532765895
# Running Train loss: 0.6805342913870394
# Running Train loss: 0.6787981490655379
# Running Train loss: 0.6769556621278542
# Running Train loss: 0.6757915803241386
# Running Train loss: 0.6747730977886872
# Running Train loss: 0.6735910420776695
# Running Train loss: 0.6716760950429099
# Running Train loss: 0.6701649433247135
# Running Train loss: 0.6686330430790888
# Running Train loss: 0.6671600057990307
# Running Train loss: 0.6654441676719088
# Running Train loss: 0.6640313713174117
# Running Train loss: 0.6629337835145164
# Running Train loss: 0.6611585256218495
# Running Train loss: 0.6594895818270743
# Running Train loss: 0.6584305515235683
# Running Train loss: 0.6568802499051751
# Running Train loss: 0.6551385309380764
# Running Train loss: 0.6543335188435365
# Running Train loss: 0.6535929180554563
# Running Train loss: 0.6528911441057718
# Running Train loss: 0.6514637143935187
# Running Train loss: 0.6502258861185731
# Running Train loss: 0.648658579046076
# Running Train loss: 0.647364269066977
# Running Train loss: 0.6461690683229312
# Running Train loss: 0.6445824654897054
# Running Train loss: 0.6441968566555517
# Running Train loss: 0.6431220949485602
# Running Train loss: 0.6420905624482498
# Running Train loss: 0.6405242756989441
# Running Train loss: 0.6391093028373406
# Running Train loss: 0.6375073555345628
# Running Train loss: 0.6359625346109222
# Running Train loss: 0.6348715606447938
# Running Train loss: 0.6336019793856877
# Running Train loss: 0.6322790451107486
# Running Train loss: 0.6310153265762176
# Running Train loss: 0.6294259331547297
# Running Train loss: 0.6285471183994708
# Running Train loss: 0.6272836313316017
# Running Train loss: 0.6271843050207411
# Running Train loss: 0.6268115889611123
# Running Train loss: 0.6260626709987689
# Running Train loss: 0.6248837323308741
# Running Train loss: 0.6237726618877399
# Running Train loss: 0.6222422860562802
# Running Train loss: 0.6210359838614211
# Running Train loss: 0.6201495842441268
# Running Train loss: 0.6200520624594054
# Running Train loss: 0.6189938566107073
# Running Train loss: 0.6177276854790174
# Running Train loss: 0.6162533877086054
# Running Train loss: 0.6148802150006688
# Running Train loss: 0.6135000117668291
# Running Train loss: 0.6120352001356861
# Running Train loss: 0.6110853211446242
# Running Train loss: 0.6097815729159963
# Running Train loss: 0.6084578424602388
# Running Train loss: 0.6073755702456912
# Running Train loss: 0.6062530269790553
# Running Train loss: 0.6047911544121913
# Running Train loss: 0.6040497313785765
# Running Train loss: 0.6025443889576533
# Running Train loss: 0.6013233365171408
# Running Train loss: 0.600214208055914
# Running Train loss: 0.5992199503542746
# Running Train loss: 0.5982815772076506
# Running Train loss: 0.5974682953143329
# Running Train loss: 0.5973552491722232
# Running Train loss: 0.5965432952006542
# Running Train loss: 0.5957962685089181
# Running Train loss: 0.5948921340609217
# Running Train loss: 0.5943466479264694
# Running Train loss: 0.5934221556345964
# Running Train loss: 0.5926474314236367
# Running Train loss: 0.5916354010999203
# Running Train loss: 0.591003663116201
# Running Train loss: 0.5903421577955172
# Running Train loss: 0.5902441677771952
# Running Train loss: 0.5895586541017234
# Running Train loss: 0.5904681741561688
# Running Train loss: 0.5902016410876191
# Running Train loss: 0.5899887953360542
# Running Train loss: 0.5891969743595776
# Running Train loss: 0.5891811512514409
# Running Train loss: 0.5888626150993838
# Running Train loss: 0.5887764298725987
# Running Train loss: 0.5885000014214555
# Running Train loss: 0.5880610527619514
# Running Train loss: 0.5871461883064483
# Running Train loss: 0.5865455877495138
# Running Train loss: 0.5864640363782155
# Running Train loss: 0.5858110071081232
# Running Train loss: 0.585206345796747
# Running Train loss: 0.5845356747750344
# Running Train loss: 0.5847297569585813
# Running Train loss: 0.5855204537912521
# Running Train loss: 0.585261541048205
# Running Train loss: 0.5844684400802963
# Running Train loss: 0.5857090770919374
# Running Train loss: 0.5857905630469322
# Running Train loss: 0.5853273336121694
# Running Train loss: 0.5857949097411069
# Running Train loss: 0.5854168163129577
# Running Train loss: 0.5853844465279957
# Running Train loss: 0.5844935613047135
# Running Train loss: 0.5835453321731935
# Running Train loss: 0.5825865750654518
# Running Train loss: 0.581979725188904
# Running Train loss: 0.5811818751778143
# Running Train loss: 0.5807202991533589
# Running Train loss: 0.581462430425104
# Running Train loss: 0.5807373076869844
# Running Train loss: 0.5803018716768813
# Running Train loss: 0.5792099000517384
# Running Train loss: 0.5786965560263548
# Running Train loss: 0.5782009683873343
# Running Train loss: 0.5774695020054981
# Running Train loss: 0.5774172077159239
# Running Train loss: 0.576737600061948
# Running Train loss: 0.5757637413053573
# Running Train loss: 0.5753813644664155
# Running Train loss: 0.5748211487527158
# Running Train loss: 0.5742587373596639
# Running Train loss: 0.573921938942638
# Running Train loss: 0.5738827011547982
# Running Train loss: 0.5733685100873807
# Running Train loss: 0.5724458871084955
# Running Train loss: 0.5715750941530646
# Running Train loss: 0.5709468189553164
# Running Train loss: 0.5699919555106281
# Running Train loss: 0.570305696720707
# Running Train loss: 0.5699946254455194
# Running Train loss: 0.569798924631494
# Running Train loss: 0.5695154120585446
# Running Train loss: 0.5689106695717427
# Running Train loss: 0.5684057152365536
# Running Train loss: 0.5679049356071983
# Running Train loss: 0.5673170185154056
# Running Train loss: 0.5668683461125058
# Running Train loss: 0.566608491091125
# Running Train loss: 0.5659860589075834
# Running Train loss: 0.5652726327808355
# Running Train loss: 0.5648012452326608
# Running Train loss: 0.5642674413991998
# Running Train loss: 0.5636807987555152
# Running Train loss: 0.5627307801766237
# Running Train loss: 0.5625773645513713
# Running Train loss: 0.5625615053530563
# Running Train loss: 0.5621641466464355
# Running Train loss: 0.5619875261888785
# Running Train loss: 0.5616811251381474
# Running Train loss: 0.5614952302474607
# Running Train loss: 0.5606909758959696
# Running Train loss: 0.5598974881090206
# Running Train loss: 0.5587213362372199
# Running Train loss: 0.5579625539948382
# Running Train loss: 0.5579510840621812
# Running Train loss: 0.5576174636016542
# Running Train loss: 0.5576867603692591
# Running Train loss: 0.5579174937530496
# Running Train loss: 0.5571768280768067
# Running Train loss: 0.556676944176447
# Running Train loss: 0.5564999802539882
# Running Train loss: 0.5583507437980256
# Running Train loss: 0.5576433517716147
# Running Train loss: 0.5573595215539002
# Running Train loss: 0.5582783952422811
# Running Train loss: 0.5578899137995313
# Running Train loss: 0.5584953268234795
# Running Train loss: 0.557800335830517
# Running Train loss: 0.5573531840948781
# Running Train loss: 0.5565820323007485
# Running Train loss: 0.5556256703234145
# Running Train loss: 0.5552205187838964
# Running Train loss: 0.5547583358155357
# Running Train loss: 0.5545956566434214
# Running Train loss: 0.5538718098758069
# Running Train loss: 0.5536731503591369
# Running Train loss: 0.5531329522770932
# Running Train loss: 0.552566356416587
# Running Train loss: 0.5525855006029209
# Running Train loss: 0.5524367841706495
# Running Train loss: 0.5526003814485396
# Running Train loss: 0.5527608324824336
# Running Train loss: 0.5522587133166583
# Running Train loss: 0.5522592677664084
# Running Train loss: 0.5520302176282004
# Running Train loss: 0.5512834282402859
# Running Train loss: 0.5504980548124375
# Running Train loss: 0.550089287405373
# Running Train loss: 0.5493741550926486
# Running Train loss: 0.5489831198589195
# Running Train loss: 0.5485199501371791
# Running Train loss: 0.5476452509668082
# Running Train loss: 0.547519165118958
# Running Train loss: 0.546847551523247
# Running Train loss: 0.5460729145650136
# Running Train loss: 0.5457735960755742
# Running Train loss: 0.5451693743593079
# Running Train loss: 0.5449263645473279
# Running Train loss: 0.5444813758886161
# Running Train loss: 0.543906772286637
# Running Train loss: 0.5435174461687958
# Running Train loss: 0.5428072778130871
# Running Train loss: 0.542767370150735
# Running Train loss: 0.5425456669065412
# Running Train loss: 0.5418745047756746
# Running Train loss: 0.5415626153750943
# Running Train loss: 0.5409162167675239
# Running Train loss: 0.5405537116158868
# Running Train loss: 0.5407262817331793
# Running Train loss: 0.540620544424292
# Running Train loss: 0.5406145702009318
# Running Train loss: 0.5398449669220696
# Running Train loss: 0.5394372217509211
# Running Train loss: 0.5389454937758126
# Running Train loss: 0.5391836045234184
# Running Train loss: 0.5398508953516188
# Running Train loss: 0.539357786719133
# Running Train loss: 0.5390329398892143
# Running Train loss: 0.5385528350429188
# Running Train loss: 0.5382305862198413
# Running Train loss: 0.5380598627419836
# Running Train loss: 0.5374253233950698
# Running Train loss: 0.537367296397686
# Running Train loss: 0.5366052802272899
# Running Train loss: 0.5359508889426748
# Running Train loss: 0.5358331591838871
# Running Train loss: 0.5349770431805935
# Running Train loss: 0.5340563345073474
# Running Train loss: 0.5331320919008123
# Running Train loss: 0.5321078304517316
# Running Train loss: 0.5313165021150952
# Running Train loss: 0.5314440557363577
# Running Train loss: 0.5314599352651367
# Running Train loss: 0.5308525795499756
# Running Train loss: 0.5303907022389467
# Running Train loss: 0.5301301417687134
# Running Train loss: 0.5301701034480844
# Running Train loss: 0.5326679296791553
# Running Train loss: 0.5325606770799026
# Running Train loss: 0.532106735194156
# Running Train loss: 0.5320344671937834
# Running Train loss: 0.5316214787635615
# Running Train loss: 0.5312737060782428
# Running Train loss: 0.5309453203830861
# Running Train loss: 0.5306081994440249
# Running Train loss: 0.5300674038951643
# Running Train loss: 0.5294080506512568
# Running Train loss: 0.528972503308739
# Running Train loss: 0.5287981140622054
# Running Train loss: 0.5283582904632336
# Running Train loss: 0.5280127523847941
# Running Train loss: 0.5274313697785082
# Running Train loss: 0.527014403347418
# Running Train loss: 0.5264705782878982
# Running Train loss: 0.5264728898042463
# Running Train loss: 0.5261759120223111
# Running Train loss: 0.5258693162296038
# Running Train loss: 0.5255733966479235
# Running Train loss: 0.5252079671985511
# Running Train loss: 0.5248739037530937
# Running Train loss: 0.5245792231692147
# Running Train loss: 0.5239082873351388
# Running Train loss: 0.5236004055581159
# Running Train loss: 0.5234159203022443
# Running Train loss: 0.5234682572545051
# Running Train loss: 0.5236925198928098
# Running Train loss: 0.5232792349244633
# Running Train loss: 0.522616825539858
# Running Train loss: 0.5220649739311183
# Running Train loss: 0.5216401878819278
# Running Train loss: 0.5225785157310158
# Running Train loss: 0.5223746495372285
# Running Train loss: 0.5221173876727169
# Running Train loss: 0.5216845142741277
# Running Train loss: 0.5213204797397814
# Running Train loss: 0.5209538838733493
# Running Train loss: 0.5203599254617515
# Running Train loss: 0.520697653877574
# Running Train loss: 0.5205629764848368
# Running Train loss: 0.5209958084542939
# Running Train loss: 0.5204506388207811
# Running Train loss: 0.5198706892487295
# Running Train loss: 0.5197165432452623
# Running Train loss: 0.519403678071212
# Running Train loss: 0.5188596744912268
# Running Train loss: 0.5181645420090449
# Running Train loss: 0.5174899399742907
# Running Train loss: 0.5167708175701905
# Running Train loss: 0.5164768718275186
# Running Train loss: 0.5159579623010949
# Running Train loss: 0.5155835119994279
# Running Train loss: 0.5152217436038442
# Running Train loss: 0.5152488046897608
# Running Train loss: 0.5148606603400824
# Running Train loss: 0.5142093601512846
# Running Train loss: 0.5139458264836986
# Running Train loss: 0.513542049548196
# Running Train loss: 0.5135137776253016
# Running Train loss: 0.5132941995915543
# Running Train loss: 0.5130497617017562
# Running Train loss: 0.5128624570269177
# Running Train loss: 0.5124558231540809
# Running Train loss: 0.5127235941396191
# Running Train loss: 0.5129620549357183
# Running Train loss: 0.512521150704358
# Running Train loss: 0.5125362896655988
# Running Train loss: 0.512260703708058
# Running Train loss: 0.5119734498234386
# Running Train loss: 0.5117321619668613
# Running Train loss: 0.5115945148369015
# Running Train loss: 0.5113078217484615
# Running Train loss: 0.5109859721225976
# Running Train loss: 0.5106919710477025
# Running Train loss: 0.510216562307476
# Running Train loss: 0.5097772882106034
# Running Train loss: 0.5093432785801804
# Running Train loss: 0.5090026855782327
# Running Train loss: 0.5084140630391967
# Running Train loss: 0.5086416494188792
# Running Train loss: 0.5086537298108366
# Running Train loss: 0.5084496525281349
# Running Train loss: 0.5080791685002575
# Running Train loss: 0.5078725628120204
# Running Train loss: 0.5076507389012371
# Running Train loss: 0.5073656543804661
# Running Train loss: 0.5068435688035109
# Running Train loss: 0.5065781245970272
# Running Train loss: 0.5063455637636756
# Running Train loss: 0.5061346011992434
# Running Train loss: 0.5057520915307657
# Running Train loss: 0.5053222452008509
# Running Train loss: 0.5051181127052687
# Running Train loss: 0.5048286099475426
# Running Train loss: 0.5046232862736414
# Running Train loss: 0.5041406973039889
# Running Train loss: 0.5035164138244475
# Running Train loss: 0.50290496567877
# Running Train loss: 0.5022035906167049
# Running Train loss: 0.5017886832779781
# Running Train loss: 0.5013628991281484
# Running Train loss: 0.5008416236785141
# Running Train loss: 0.5004516068864042
# Running Train loss: 0.5000264485937453
# Running Train loss: 0.5000072847181952
# Running Train loss: 0.5000447188099768
# Running Train loss: 0.499725433637539
# Running Train loss: 0.4995379364774682
# Running Train loss: 0.4993874745309353
# Running Train loss: 0.49875888834817533
# Running Train loss: 0.49847672327735015
# Running Train loss: 0.49828310379058505
# Running Train loss: 0.4978919941487771
# Running Train loss: 0.4974074889920534
# Running Train loss: 0.49698435869982993
# Running Train loss: 0.4967817753918846
# Running Train loss: 0.4963018199455399
# Running Train loss: 0.4960522516939072
# Running Train loss: 0.49576349415061044
# Running Train loss: 0.4953211012395954
# Running Train loss: 0.4950116680206927
# Running Train loss: 0.494690021768586
# Running Train loss: 0.4949568218270285
# Running Train loss: 0.4947929584130179
# Running Train loss: 0.4944534545093077
# Running Train loss: 0.49420054523256896
# Running Train loss: 0.49387375263621797
# Running Train loss: 0.49359463231048045
# Running Train loss: 0.49314602227058524
# Running Train loss: 0.49277517888637334
# Running Train loss: 0.4923503379261199
# Running Train loss: 0.4920312758293693
# Running Train loss: 0.49152113896190475
# Running Train loss: 0.49111506686187706
# Running Train loss: 0.4907002465458967
# Running Train loss: 0.49024759488397396
# Running Train loss: 0.49007440753748915
# Running Train loss: 0.4895456120178149
# Running Train loss: 0.48933206727827777
# Running Train loss: 0.4888790394009159
# Running Train loss: 0.4882702796664684
# Running Train loss: 0.4881240752296335
# Running Train loss: 0.487812905830977
# Running Train loss: 0.4874403062699871
# Running Train loss: 0.4870082184661084
# Running Train loss: 0.48696288435503254
# Running Train loss: 0.48679170597395205
# Running Train loss: 0.48650647897879223
# Running Train loss: 0.48622543588280676
# Running Train loss: 0.48615391906518657
# Running Train loss: 0.4861154039369441
# Running Train loss: 0.48584387032593973
# Running Train loss: 0.48614901861646426
# Running Train loss: 0.486287065990158
# Running Train loss: 0.4860806873820489
# Running Train loss: 0.48586567265668973
# Running Train loss: 0.4853863210249886
# Running Train loss: 0.48506080205013385
# Running Train loss: 0.4844900432836126
# Running Train loss: 0.48384555203278035
# Running Train loss: 0.48339021526156006
# Running Train loss: 0.483199348876522
# Running Train loss: 0.48313293105679866
# Running Train loss: 0.48301561342223603
# Running Train loss: 0.4826767581915715
# Running Train loss: 0.482901189410704
# Running Train loss: 0.48249632339395504
# Running Train loss: 0.4821671806166918
# Running Train loss: 0.48174956037397804
# Running Train loss: 0.48147787432846106
# Running Train loss: 0.48124793424573353
# Running Train loss: 0.48092997235484247
# Running Train loss: 0.48045531264540076
# Running Train loss: 0.47990747682642243
# Running Train loss: 0.4795429478958788
# Running Train loss: 0.47956953474422753
# Running Train loss: 0.4794728338481888
# Running Train loss: 0.47919127547990004
# Running Train loss: 0.4789524231990464
# Running Train loss: 0.4788251742399458
# Running Train loss: 0.4781926148804907
# Running Train loss: 0.4778300488319643
# Running Train loss: 0.4776727249352888
# Running Train loss: 0.4775896014911788
# Running Train loss: 0.477172098320493
# Running Train loss: 0.47686318078866374
# Running Train loss: 0.47656554134183726
# Running Train loss: 0.47629805851135065
# Running Train loss: 0.4760760305409736
# Running Train loss: 0.4755373577093943
# Running Train loss: 0.47520075980811005
# Running Train loss: 0.4753620105948152
# Running Train loss: 0.4754246553177558
# Running Train loss: 0.47501462811315565
# Running Train loss: 0.474905930197524
# Running Train loss: 0.474394851772303
# Running Train loss: 0.4741171305427043
# Running Train loss: 0.4738430047319049
# Running Train loss: 0.4735557579494023
# Running Train loss: 0.4730397527048874
# Running Train loss: 0.47297120710504936
# Running Train loss: 0.47269598497363186
# Running Train loss: 0.4724594998861221
# Running Train loss: 0.47243934262336956
# Running Train loss: 0.4728441839099922
# Running Train loss: 0.4729397505459858
# Running Train loss: 0.47283240708613955
# Running Train loss: 0.4725316734624337
# Running Train loss: 0.47222646019582093
# Running Train loss: 0.4724686274371692
# Running Train loss: 0.4724216670761246
# Running Train loss: 0.47247356582678607
# Running Train loss: 0.4721451747053608
# Running Train loss: 0.4717759326610663
# Running Train loss: 0.47153809400614244
# Running Train loss: 0.47114949922784755
# Running Train loss: 0.47082330740856115
# Running Train loss: 0.47056188624179657
# Running Train loss: 0.47029156215539597
# Running Train loss: 0.47001170031928824
# Running Train loss: 0.4697370370357137
# Running Train loss: 0.4697491998372847
# Running Train loss: 0.4699537386369157
# Running Train loss: 0.47010169320211215
# Running Train loss: 0.4701525646283237
# Running Train loss: 0.46998994467112254
# Running Train loss: 0.4697681189405645
# Running Train loss: 0.46941142045562306
# Running Train loss: 0.4690909708406301
# Running Train loss: 0.4687857780575592
# Running Train loss: 0.4684874034290971
# Running Train loss: 0.46827406279822403
# Running Train loss: 0.46792671041630296
# Running Train loss: 0.4677617048124472
# Running Train loss: 0.467351324221345
# Running Train loss: 0.4671684622348465
# Running Train loss: 0.4671246962223553
# Running Train loss: 0.46669617995856927
# Running Train loss: 0.46631734123490504
# Running Train loss: 0.4661608540684615
# Running Train loss: 0.46586644611120853
# Running Train loss: 0.4656759470720876
# Running Train loss: 0.4653901441000667
# Running Train loss: 0.464933349427424
# Running Train loss: 0.4646105610823036
# Running Train loss: 0.4643314785453591
# Running Train loss: 0.4640701383860052
# Running Train loss: 0.46368980516938013
# Running Train loss: 0.46320235342566485
# Running Train loss: 0.4628169716824595
# Running Train loss: 0.46264824544163385
# Running Train loss: 0.46264226231141947
# Running Train loss: 0.46228523369302055
# Running Train loss: 0.46241058139251423
# Running Train loss: 0.4620915248255631
# Running Train loss: 0.46174344734090905
# Running Train loss: 0.4612093655655177
# Running Train loss: 0.4608476258698822
# Running Train loss: 0.4606021450123479
# Running Train loss: 0.4606071814376208
# Running Train loss: 0.4603855080298475
# Running Train loss: 0.46002215356745574
# Running Train loss: 0.4599924473826019
# Running Train loss: 0.45980739978452523
# Running Train loss: 0.45967376257904663
# Running Train loss: 0.4595094137846509
# Running Train loss: 0.4591041086943366
# Running Train loss: 0.4588987100394253
# Running Train loss: 0.45896200927769304
# Running Train loss: 0.4588490529957467
# Running Train loss: 0.4587080566049228
# Running Train loss: 0.4583988712467064
# Running Train loss: 0.45794186996076497
# Running Train loss: 0.45747400204403493
# Running Train loss: 0.4571122930546476
# Running Train loss: 0.456850036329618
# Running Train loss: 0.45650725037535983
# Running Train loss: 0.4562916659118997
# Running Train loss: 0.4561805674771093
# Running Train loss: 0.456120480160842
# Running Train loss: 0.45575588706932224
# Running Train loss: 0.4555083618669731
# Running Train loss: 0.45545798541047844
# Running Train loss: 0.45506896388716994
# Running Train loss: 0.45475653491997986
# Running Train loss: 0.45473250524695974
# Running Train loss: 0.4545057282816725
# Running Train loss: 0.4545383273684119
# Running Train loss: 0.45415763374626267
# Running Train loss: 0.4539686308771594
# Running Train loss: 0.4535216328675271
# Running Train loss: 0.4531949229058948
# Running Train loss: 0.45305983073852857
# Running Train loss: 0.45274175501164093
# Running Train loss: 0.4523709476104353
# Running Train loss: 0.4522011571660124
# Running Train loss: 0.45205692122123337
# Running Train loss: 0.4519446440388881
# Running Train loss: 0.45175069184756717
# Running Train loss: 0.45211875674260016
# Running Train loss: 0.4519499648850288
# Running Train loss: 0.4518625755728311
# Running Train loss: 0.45169503502866143
# Running Train loss: 0.45135683844365726
# Running Train loss: 0.45127284546789964
# Running Train loss: 0.45110056465922194
# Running Train loss: 0.4507785379379662
# Running Train loss: 0.4505950138696189
# Running Train loss: 0.4505652944969408
# Running Train loss: 0.45033848632045864
# Running Train loss: 0.4503229445673102
# Running Train loss: 0.4502948127363039
# Running Train loss: 0.4500941066891494
# Running Train loss: 0.4500462783388345
# Running Train loss: 0.44978733310558877
# Running Train loss: 0.44952387701218516
# Running Train loss: 0.44978227150611944
# Running Train loss: 0.45008775543609114
# Running Train loss: 0.4499145992680224
# Running Train loss: 0.4498803515931921
# Running Train loss: 0.44994423560700253
# Running Train loss: 0.4500984960815787
# Running Train loss: 0.45003115866195603
# Running Train loss: 0.4501468407788447
# Running Train loss: 0.4500195719434589
# Running Train loss: 0.44978225360361246
# Running Train loss: 0.44949556639680943
# Running Train loss: 0.44931358962333035
# Running Train loss: 0.44911149346969537
# Running Train loss: 0.44891740387001783
# Running Train loss: 0.44876901576693534
# Running Train loss: 0.4488149563483191
# Running Train loss: 0.4487018448830493
# Running Train loss: 0.44877215629114825
# Running Train loss: 0.44863279373959564
# Running Train loss: 0.44852196909662145
# Running Train loss: 0.4485496013378342
# Running Train loss: 0.44845201998111517
# Running Train loss: 0.44841064711411793
# Running Train loss: 0.4482907908228792
# Running Train loss: 0.44816227674553805
# Running Train loss: 0.4479173385214694
# Running Train loss: 0.4475472537720439
# Running Train loss: 0.4472020663667557
# Running Train loss: 0.44706700268038196
# Running Train loss: 0.44724588903432105
# Running Train loss: 0.44729833512082434
# Running Train loss: 0.44721588614845165
# Running Train loss: 0.44738027661866536
# Running Train loss: 0.4476358601974009
# Running Train loss: 0.44740195764871066
# Running Train loss: 0.44736440261731497
# Running Train loss: 0.44731175184455646
# Running Train loss: 0.44741770116419627
# Running Train loss: 0.4470899715147117
# Running Train loss: 0.44694298222114187
# Running Train loss: 0.4469345493619794
# Running Train loss: 0.446651361678094
# Running Train loss: 0.44636825140884945
# Running Train loss: 0.44609608445061394
# Running Train loss: 0.44588201624705553
# Running Train loss: 0.44568262103274636
# Running Train loss: 0.4455673566619962
# Running Train loss: 0.44561645359816876
# Running Train loss: 0.4454282962809085
# Running Train loss: 0.44512393529993605
# Running Train loss: 0.44487466542461584
# Running Train loss: 0.4446461461315867
# Running Train loss: 0.44476558222609053
# Running Train loss: 0.44492663671819677
# Running Train loss: 0.4446653368407199
# Running Train loss: 0.4445209730886393
# Running Train loss: 0.44442242482851
# Running Train loss: 0.4442233673474762
# Running Train loss: 0.4438705983186009
# Running Train loss: 0.4437981315057374
# Running Train loss: 0.4439023128749275
# Running Train loss: 0.4438165945961438
# Running Train loss: 0.44356580762889797
# Running Train loss: 0.44326872282129315
# Running Train loss: 0.4430076924454807
# Running Train loss: 0.44274637300546027
# Running Train loss: 0.44253547237699103
# Running Train loss: 0.4423859028849337
# Running Train loss: 0.4420537640992862
# Running Train loss: 0.44191357219166344
# Running Train loss: 0.4417097767194112
# Running Train loss: 0.44139658325079795
# Running Train loss: 0.44130945912052916
# Running Train loss: 0.44103840828994517
# Running Train loss: 0.4408734112550826
# Running Train loss: 0.4407419008633639
# Running Train loss: 0.44046037771192975
# Running Train loss: 0.44018171570458253
# Running Train loss: 0.43996636666005845
# Running Train loss: 0.43991732786883386
# Running Train loss: 0.4397980229029389
# Running Train loss: 0.43964312269598965
# Running Train loss: 0.43949814135911036
# Running Train loss: 0.43954494540217665
# Running Train loss: 0.4392539836880685
# Running Train loss: 0.4390701610181067
# Running Train loss: 0.439128908956012
# Running Train loss: 0.4388888889518769
# Running Train loss: 0.4385929832014535
# Running Train loss: 0.43854620672940176
# Running Train loss: 0.4386797909779254
# Running Train loss: 0.43872497661353704
# Running Train loss: 0.43843263139595856
# Running Train loss: 0.4384517553815574
# Running Train loss: 0.43819677993703426
# Running Train loss: 0.4381933070012721
# Running Train loss: 0.43796840359820743
# Running Train loss: 0.4377264021545328
# Running Train loss: 0.43735671655608044
# Running Train loss: 0.43734747364061843
# Running Train loss: 0.43713358519768536
# Running Train loss: 0.4371499051868405
# Running Train loss: 0.43690329433921826
# Running Train loss: 0.43676127194880676
# Running Train loss: 0.43651921531084126
# Running Train loss: 0.43643309643813794
# Running Train loss: 0.4363096852224475
# Running Train loss: 0.43600832649526444
# Running Train loss: 0.4359986378349103
# Running Train loss: 0.4362736659207542
# Running Train loss: 0.43624864464125984
# Running Train loss: 0.4360633989780257
# Running Train loss: 0.43609104062672016
# Running Train loss: 0.43587983398842006
# Running Train loss: 0.43556394072400983
# Running Train loss: 0.43519848714020687
# Running Train loss: 0.43499011788968667
# Running Train loss: 0.4346145695134213
# Running Train loss: 0.4343818293729666
# Running Train loss: 0.4341544736990658
# Running Train loss: 0.43405386506885696
# Running Train loss: 0.43397428609227734
# Running Train loss: 0.43375706148397236
# Running Train loss: 0.4335223263963496
# Running Train loss: 0.4332281471762413
# Running Train loss: 0.43294515670714645
# Running Train loss: 0.43275099692864266
# Running Train loss: 0.4326033770882835
# Running Train loss: 0.4325253876172293
# Running Train loss: 0.43243796012815466
# Running Train loss: 0.432153087894617
# Running Train loss: 0.43200054240733754
# Running Train loss: 0.4320465846846141
# Running Train loss: 0.431837277984397
# Running Train loss: 0.4319848884070425
# Running Train loss: 0.4317220827980229
# Running Train loss: 0.4317077571301268
# Running Train loss: 0.43169697125240697
# Running Train loss: 0.4317187389894077
# Running Train loss: 0.4318903440402614
# Running Train loss: 0.43178850380207995
# Running Train loss: 0.4316085883142767
# Running Train loss: 0.43133243151200124
# Running Train loss: 0.4311299262812636
# Running Train loss: 0.4308275723317018
# Running Train loss: 0.43085686187497924
# Running Train loss: 0.4308426088374774
# Running Train loss: 0.4308750256743966
# Running Train loss: 0.43082063686896294
# Running Train loss: 0.4308333695086588
# Running Train loss: 0.4307103717769757
# Running Train loss: 0.43049656087911226
# Running Train loss: 0.4304121377201855
# Running Train loss: 0.43033443763096485
# Running Train loss: 0.43013907159775827
# Running Train loss: 0.42988706812986477
# Running Train loss: 0.4296916082154873
# Running Train loss: 0.4294804026231621
# Running Train loss: 0.42919734490266603
# Running Train loss: 0.42915920147131525
# Running Train loss: 0.4290317574296473
# Running Train loss: 0.42893056652435596
# Running Train loss: 0.42887762967665594
# Running Train loss: 0.428721093748468
# Running Train loss: 0.4284386851842568
# Running Train loss: 0.4283472935338775
# Running Train loss: 0.42835881417100735
# Running Train loss: 0.4281431356966495
# Running Train loss: 0.42799206079541147
# Running Train loss: 0.4277789497268414
# Running Train loss: 0.42763036453830877
# Running Train loss: 0.4275801350692829
# Running Train loss: 0.4273366991263717
# Running Train loss: 0.4270693476702537
# Running Train loss: 0.4268899514990033
# Running Train loss: 0.4265397606003616
# Running Train loss: 0.4263415339414854
# Running Train loss: 0.42628949631263713
# Running Train loss: 0.4261351494389401
# Running Train loss: 0.4259658303450454
# Running Train loss: 0.4256694218895866
# Running Train loss: 0.42543254273941766
# Running Train loss: 0.4253155295044331
# Running Train loss: 0.4251138072636888
# Running Train loss: 0.42507788974099453
# Running Train loss: 0.4252978523347842
# Running Train loss: 0.4251741098497754
# Running Train loss: 0.4251836639847241
# Running Train loss: 0.42498696450213375
# Running Train loss: 0.42481717640814715
# Running Train loss: 0.42469869006355954
# Running Train loss: 0.4245435932680266
# Running Train loss: 0.42436572535735806
# Running Train loss: 0.4240937838167475
# Running Train loss: 0.423973734576723
# Running Train loss: 0.4237978330990916
# Running Train loss: 0.42363694867714735
# Running Train loss: 0.4235661512873705
# Running Train loss: 0.423377988424611
# Running Train loss: 0.4231462991226089
# Running Train loss: 0.42292590033973404
# Running Train loss: 0.42267387047611765
# Running Train loss: 0.42239310305187666
# Running Train loss: 0.42225944905264956
# Running Train loss: 0.42208578317581513
# Running Train loss: 0.42191289688293643
# Running Train loss: 0.4218187419495064
# Running Train loss: 0.42159629984257313
# Running Train loss: 0.4213737289597505
# Running Train loss: 0.4216292119100547
# Running Train loss: 0.4220640364023549
# Running Train loss: 0.42266133651708276
# Running Train loss: 0.42287225445206655
# Running Train loss: 0.42295103047192667
# Running Train loss: 0.42305873026991303
# Running Train loss: 0.42305974586945
# Running Train loss: 0.42300563444116207
# Running Train loss: 0.4233204883195105
# Running Train loss: 0.4233835927794708
# Running Train loss: 0.4234249594801959
# Running Train loss: 0.4233001747503806
# Running Train loss: 0.4231900623531224
# Running Train loss: 0.4232677206467678
# Running Train loss: 0.4234779486573781
# Running Train loss: 0.4234866219499592
# Running Train loss: 0.4234409926772568
# Running Train loss: 0.42339026608536895
# Running Train loss: 0.42314231059742424
# Running Train loss: 0.4229664301445302
# Running Train loss: 0.4228305192822117
# Running Train loss: 0.4226204660262909
# Running Train loss: 0.4224241162769328
# Running Train loss: 0.42246288027561885
# Running Train loss: 0.4223437639718655
# Running Train loss: 0.4222387113689594
# Running Train loss: 0.42215104007653975
# Running Train loss: 0.4222292730304211
# Running Train loss: 0.4220832703269531
# Running Train loss: 0.4219405472445555
# Running Train loss: 0.42193187517461495
# Running Train loss: 0.4217395112960003
# Running Train loss: 0.4215849076763656
# Running Train loss: 0.42145840061265366
# Running Train loss: 0.4212095019958055
# Running Train loss: 0.42104035834526726
# Running Train loss: 0.4209573771770014
# Running Train loss: 0.42080634743997186
# Running Train loss: 0.4206975142436999
# Running Train loss: 0.42051634401992777
# Running Train loss: 0.4202391837900866
# Running Train loss: 0.42022554700917264
# Running Train loss: 0.41996198937269374
# Running Train loss: 0.41976906539795034
# Running Train loss: 0.4199171314431049
# Running Train loss: 0.41979055832505996
# Running Train loss: 0.4198760411989711
# Running Train loss: 0.4196842570538582
# Running Train loss: 0.41966997985856247
# Running Train loss: 0.4195393226856381
# Running Train loss: 0.41943369185613405
# Running Train loss: 0.41942120603842137
# Running Train loss: 0.41941978396265556
# Running Train loss: 0.41929625672156406
# Running Train loss: 0.4192039912947229
# Running Train loss: 0.41909093375817796
# Running Train loss: 0.4192843299243728
# Running Train loss: 0.41931167002885966
# Running Train loss: 0.4193239828063683
# Running Train loss: 0.41914507448267224
# Running Train loss: 0.418864198448221
# Running Train loss: 0.41875987172342927
# Running Train loss: 0.4186412837302339
# Running Train loss: 0.41849521002079026
# Running Train loss: 0.4182213694598209
# Running Train loss: 0.4180419566252798
# Running Train loss: 0.417774733350972
# Running Train loss: 0.4175632245254151
# Running Train loss: 0.4173812930581269
# Running Train loss: 0.41747061332183094
# Running Train loss: 0.41722414909908884
# Running Train loss: 0.4170696903873647
# Running Train loss: 0.41700543525429773
# Running Train loss: 0.41688054509360695
# Running Train loss: 0.41667911484436965
# Running Train loss: 0.4165922290409583
# Running Train loss: 0.4165083186930855
# Running Train loss: 0.4164570528644339
# Running Train loss: 0.41655119930926177
# Running Train loss: 0.41636700628459933
# Running Train loss: 0.4162520020336922
# Running Train loss: 0.416138152929416
# Running Train loss: 0.41592658804961585
# Running Train loss: 0.4157496829761399
# Running Train loss: 0.41575719973942526
# Running Train loss: 0.41574418998943985
# Running Train loss: 0.41560373784881743
# Running Train loss: 0.4153673528661445
# Running Train loss: 0.4151764382764829
# Running Train loss: 0.4150741728702865
# Running Train loss: 0.414917143891062
# Running Train loss: 0.4148848521648943
# Running Train loss: 0.41465827363429875
# Running Train loss: 0.41448669163797397
# Running Train loss: 0.41435179749871015
# Running Train loss: 0.41416562076006
# Running Train loss: 0.413932894276347
# Running Train loss: 0.41375043500898384
# Running Train loss: 0.41369990920157806
# Running Train loss: 0.4136563683619215
# Running Train loss: 0.41352901399631425
# Running Train loss: 0.4133193747564981
# Running Train loss: 0.4130705323239619
# Running Train loss: 0.41305801537229503
# Running Train loss: 0.41291622562012126
# Running Train loss: 0.41266600662272396
# Running Train loss: 0.4124850203649819
# Running Train loss: 0.4121784669832627
# Running Train loss: 0.4121771948557833
# Running Train loss: 0.411883877501293
# Running Train loss: 0.41171414625003105
# Running Train loss: 0.41158852469683316
# Running Train loss: 0.411369071237136
# Running Train loss: 0.4111411002420244
# Running Train loss: 0.41084912515996236
# Running Train loss: 0.41080941780178115
# Running Train loss: 0.41069808667959945
# Running Train loss: 0.4104261589754852
# Running Train loss: 0.4102745300480004
# Running Train loss: 0.4100536716513137
# Running Train loss: 0.40972484484404686
# Running Train loss: 0.40957715139049244
# Running Train loss: 0.40945270068981904
# Running Train loss: 0.409434577020069
# Running Train loss: 0.40935873246941823
# Running Train loss: 0.40916900098285514
# Running Train loss: 0.40917339510514006
# Running Train loss: 0.4090723266380531
# Running Train loss: 0.4089677456384286
# Running Train loss: 0.40888516985700746
# Running Train loss: 0.4088548702877587
# Running Train loss: 0.40879976089157716
# Running Train loss: 0.4087382568747719
# Running Train loss: 0.4086999100605224
# Running Train loss: 0.4090078608196254
# Running Train loss: 0.40922108475204333
# Running Train loss: 0.4091535966324735
# Running Train loss: 0.40923087452115703
# Running Train loss: 0.40906873729585086
# Running Train loss: 0.4088556129236175
# Running Train loss: 0.40889487952914233
# Running Train loss: 0.4088687833149808
# Running Train loss: 0.4089337009087054
# Running Train loss: 0.40895306534970866
# Running Train loss: 0.4089206559065271
# Running Train loss: 0.40878359918508494
# Running Train loss: 0.40864985360001976
# Running Train loss: 0.40851643018869416
# Running Train loss: 0.4084573696046567
# Running Train loss: 0.4085019542284366
# Running Train loss: 0.4085323771980635
# Running Train loss: 0.40843246063125405
# Running Train loss: 0.40859403137048983
# Running Train loss: 0.40862866497002387
# Running Train loss: 0.40854394813706746
# Running Train loss: 0.4084806684669148
# Running Train loss: 0.4088067507312224
# Running Train loss: 0.40915408239911955
# Running Train loss: 0.40950042167368034
# Running Train loss: 0.4093384088655247
# Running Train loss: 0.40917195144501484
# Running Train loss: 0.40939678619937014
# Running Train loss: 0.40939135938895205
# Running Train loss: 0.4094113915571286
# Running Train loss: 0.4093120570879918
# Running Train loss: 0.40947390370867226
# Running Train loss: 0.40935093058667926
# Running Train loss: 0.40921599516218315
# Running Train loss: 0.4092297455034226
# Running Train loss: 0.4091332135006822
# Running Train loss: 0.409114422408784
# Running Train loss: 0.4090503028210833
# Running Train loss: 0.40899048552003
# Running Train loss: 0.40888882439138957
# Running Train loss: 0.4090096245697503
# Running Train loss: 0.40896012375380725
# Running Train loss: 0.40878322651099
# Running Train loss: 0.40880007695000226
# Running Train loss: 0.40878471460071253
# Running Train loss: 0.40877643282800596
# Running Train loss: 0.40861120555738867
# Running Train loss: 0.40867103266172594
# Running Train loss: 0.40865843941828883
# Running Train loss: 0.4086069491110286
# Running Train loss: 0.40853471353005916
# ...
# Running Train loss: 0.3822376911846421
# Running Train loss: 0.3821582653872455
# Running Train loss: 0.3820282433354426
# Running Train loss: 0.3819221003469685
# Running Train loss: 0.38185931823540414
# Running Train loss: 0.3818450264813871
# Running Train loss: 0.3817265551166104
# Running Train loss: 0.3816227076442841
# Running Train loss: 0.3815820480140776
# Running Train loss: 0.38149864330725136
# Running Train loss: 0.38156728240350885
# Running Train loss: 0.38168575731345844
# Running Train loss: 0.381535593896076
# Running Train loss: 0.38143546817766777
# Running Train loss: 0.381360300117259
# Running Train loss: 0.3813457633861062
# Running Train loss: 0.38138608860103906
# Running Train loss: 0.38137028156119296
# Running Train loss: 0.3813590070949497
# Running Train loss: 0.38140247294913937
# Running Train loss: 0.38131523825991226
# Running Train loss: 0.38121184276743225
# Running Train loss: 0.3811828082070992
# Running Train loss: 0.38106249851441787
# Running Train loss: 0.38104432682247047
# Running Train loss: 0.38098895691849805
# Running Train loss: 0.38097329796174495
# Running Train loss: 0.381080808890084
# Running Train loss: 0.3809690839930368
# Running Train loss: 0.3809168950691953
# Running Train loss: 0.3808453143869867
# Running Train loss: 0.3807310225304945
# Running Train loss: 0.38072101008726295
# Running Train loss: 0.3806498421904967
# Running Train loss: 0.38063060975407687
# Running Train loss: 0.38055863414015345
# Running Train loss: 0.38075948566829604
# Running Train loss: 0.38076005585282846
# Running Train loss: 0.38062331597048776
# Running Train loss: 0.38052266432131027
# Running Train loss: 0.3803516808919431
# Running Train loss: 0.38035940436301735
# Running Train loss: 0.38037853922991705
# Running Train loss: 0.38032790666321026
# Running Train loss: 0.38018600520790685
# Running Train loss: 0.3800169250444241
# Running Train loss: 0.37998119667216623
# Running Train loss: 0.37995793400348893
# Running Train loss: 0.37978754243570695
# Running Train loss: 0.3796402597242978
# Running Train loss: 0.37944881897309474
# Running Train loss: 0.37934470044295865
# Running Train loss: 0.3791803410673078
# Running Train loss: 0.3790362992528023
# Running Train loss: 0.378963432632114
# Running Train loss: 0.378856344505661
# Running Train loss: 0.3787962196478269
# Running Train loss: 0.3786447830366505
# Running Train loss: 0.3785090140353349
# Running Train loss: 0.3783871918947399
# Running Train loss: 0.3782746515357319
# Running Train loss: 0.3781613465124793
# Running Train loss: 0.37807439861887
# Running Train loss: 0.3781677797476089
# Running Train loss: 0.3780636574106702
# Running Train loss: 0.37801796929184295
# Running Train loss: 0.3779108288292833
# Running Train loss: 0.37786446615407604
# Running Train loss: 0.377829829686751
# Running Train loss: 0.37781649083117075
# Running Train loss: 0.3777507356711124
# Running Train loss: 0.37758300394420735
# Running Train loss: 0.37754764663551665
# Running Train loss: 0.3774241185173505
# Running Train loss: 0.3772802755753906
# Running Train loss: 0.3771557493108181
# Running Train loss: 0.37703405340399704
# Running Train loss: 0.377233837836953
# Running Train loss: 0.37733425492067346
# Running Train loss: 0.37738304786544474
# Running Train loss: 0.3772527919237524
# Running Train loss: 0.37719934828739604
# Running Train loss: 0.3772708821704267
# Running Train loss: 0.377491841982408
# Running Train loss: 0.37741685812329123
# Running Train loss: 0.3773970126565816
# Running Train loss: 0.3772605583568126
# Running Train loss: 0.37720904051696696
# Running Train loss: 0.3770701453344103
# Running Train loss: 0.37689819424146515
# Running Train loss: 0.37675590955926846
# Running Train loss: 0.3765908271991091
# Running Train loss: 0.3765211228139303
# Running Train loss: 0.37643099345580666
# Running Train loss: 0.37632688658468794
# Running Train loss: 0.37620573776642596
# Running Train loss: 0.3760610129319406
# Running Train loss: 0.3759437464778116
# Running Train loss: 0.37582075355576633
# Running Train loss: 0.3757605854274042
# Running Train loss: 0.3755980917884187
# Running Train loss: 0.3755748606362369
# Running Train loss: 0.37550490616631493
# Running Train loss: 0.37566910961314787
# Running Train loss: 0.3756579310834032
# Running Train loss: 0.3755382190909461
# Running Train loss: 0.37540958513039563
# Running Train loss: 0.3752867139611472
# Running Train loss: 0.37517440083992903
# Running Train loss: 0.37499777337758794
# Running Train loss: 0.3749192116579839
# Running Train loss: 0.37496529349994484
# Running Train loss: 0.37485347528087154
# Running Train loss: 0.3748564923801595
# Running Train loss: 0.3748483585093931
# Running Train loss: 0.3747664878829422
# Running Train loss: 0.3747196167278908
# Running Train loss: 0.3747315852201555
# Running Train loss: 0.3746504836924484
# Running Train loss: 0.37461854986562654
# Running Train loss: 0.37451807395766745
# Running Train loss: 0.37445729584864157
# Running Train loss: 0.3745249729163767
# Running Train loss: 0.374407586018791
# Running Train loss: 0.3742731568422549
# Running Train loss: 0.3741200181288861
# Running Train loss: 0.3740230117938223
# Running Train loss: 0.3740275765462959
# Running Train loss: 0.37397793754387426
# Running Train loss: 0.3738811562662242
# Running Train loss: 0.3738239632045987
# Running Train loss: 0.37370663645500046
# Running Train loss: 0.3735905762732399
# Running Train loss: 0.3734840987511799
# Running Train loss: 0.3734221981550654
# Running Train loss: 0.37335166088921923
# Running Train loss: 0.3732651612272503
# Running Train loss: 0.373253673623218
# Running Train loss: 0.3732420653838107
# Running Train loss: 0.3731699852003785
# Running Train loss: 0.3730894944536385
# Running Train loss: 0.3730050383688927
# Running Train loss: 0.37290130317102443
# Running Train loss: 0.3727731151684943
# Running Train loss: 0.37266021946678984
# Running Train loss: 0.3726498534678578
# Running Train loss: 0.3725261071223394
# Running Train loss: 0.3724333750126778
# Running Train loss: 0.37238846732391007
# Running Train loss: 0.37230384395426047
# Running Train loss: 0.3721635641478127
# Running Train loss: 0.3720602946577459
# Running Train loss: 0.3719462584433911
# Running Train loss: 0.3718696952975634
# Running Train loss: 0.3717588952814157
# Running Train loss: 0.371708067020915
# Running Train loss: 0.37158845039603106
# Running Train loss: 0.3715417319571866
# Running Train loss: 0.3714217706184598
# Running Train loss: 0.37132867375360784
# Running Train loss: 0.37131672532815074
# Running Train loss: 0.3713468065147166
# Running Train loss: 0.3713544843145765
# Running Train loss: 0.3711855095344752
# Running Train loss: 0.37122611994101373
# Running Train loss: 0.37111405885657117
# Running Train loss: 0.37099561282739885
# Running Train loss: 0.37091534271193066
# Running Train loss: 0.37096480016629585
# Running Train loss: 0.37085407151289246
# Running Train loss: 0.3708079948053999
# Running Train loss: 0.37065474376543195
# Running Train loss: 0.3704944160143962
# Running Train loss: 0.37039064835208396
# Running Train loss: 0.37029312335184744
# Running Train loss: 0.3701901235055825
# Running Train loss: 0.37006020043168364
# Running Train loss: 0.3699918757892436
# Running Train loss: 0.3698929955402125
# Running Train loss: 0.3697217601346832
# Running Train loss: 0.369565149947264
# Running Train loss: 0.36948373198779255
# Running Train loss: 0.3693994579348063
# Running Train loss: 0.3693279520523169
# Running Train loss: 0.3693311742707074
# Running Train loss: 0.369266802776758
# Running Train loss: 0.3693031295256736
# Running Train loss: 0.3692447958309173
# Running Train loss: 0.3691196638695423
# Running Train loss: 0.3691039659050301
# Running Train loss: 0.36895410690273417
# Running Train loss: 0.36888431512930236
# Running Train loss: 0.3688141368065176
# Running Train loss: 0.36882902904369436
# Running Train loss: 0.3687108795391142
# Running Train loss: 0.3687168574767639
# Running Train loss: 0.3685823386729835
# Running Train loss: 0.3685049606658514
# Running Train loss: 0.36836770235462535
# Running Train loss: 0.3682666963848522
# Running Train loss: 0.36822303642275866
# Running Train loss: 0.3682096168815701
# Running Train loss: 0.3681424388299968
# Running Train loss: 0.3680826669101054
# Running Train loss: 0.36799461794754496
# Running Train loss: 0.3678435512492812
# Running Train loss: 0.36772201601557136
# Running Train loss: 0.36768092959514165
# Running Train loss: 0.36776076787598916
# Running Train loss: 0.36768205248508473
# Running Train loss: 0.36752645050955784
# Running Train loss: 0.3675124284075216
# Running Train loss: 0.3674934844005668
# Running Train loss: 0.3674514398352719
# Running Train loss: 0.36737271291208823
# Running Train loss: 0.3674746516881124
# Running Train loss: 0.36735452929760554
# Running Train loss: 0.36723864092764896
# Running Train loss: 0.36710828676442864
# Running Train loss: 0.36701908035703795
# Running Train loss: 0.3670344354785098
# Running Train loss: 0.3669494843828076
# Running Train loss: 0.36687776831075725
# Running Train loss: 0.36686381483895447
# Running Train loss: 0.3667323373781733
# Running Train loss: 0.36659318245248246
# Running Train loss: 0.3664350406808773
# Running Train loss: 0.3663083930516313
# Running Train loss: 0.36625159687583975
# Running Train loss: 0.3661290331140216
# Running Train loss: 0.3660005751001166
# Running Train loss: 0.36586903789658587
# Running Train loss: 0.3657822483079906
# Running Train loss: 0.365659251536635
# Running Train loss: 0.3655288775720839
# Running Train loss: 0.3655605792502562
# Running Train loss: 0.3654725453726995
# Running Train loss: 0.3654411162647181
# Running Train loss: 0.365317627269858
# Running Train loss: 0.3651669504316231
# Running Train loss: 0.3651597861180756
# Running Train loss: 0.36524979491133375
# Running Train loss: 0.36520452995949865
# Running Train loss: 0.36508815905125735
# Running Train loss: 0.36501952304036184
# Running Train loss: 0.36493508144422615
# Running Train loss: 0.3647699864741221
# Running Train loss: 0.3647548048409066
# Running Train loss: 0.3646791041197287
# Running Train loss: 0.3646019825848907
# Running Train loss: 0.36446158140503543
# Running Train loss: 0.3643998141715225
# Running Train loss: 0.3643673399451482
# Running Train loss: 0.36433456293014516
# Running Train loss: 0.36435396884742105
# Running Train loss: 0.3643488410005154
# Running Train loss: 0.3643211646964341
# Running Train loss: 0.36434946704064786
# Running Train loss: 0.3642630221948295
# Running Train loss: 0.36425753499235586
# Running Train loss: 0.36419384983417236
# Running Train loss: 0.3640572887652802
# Running Train loss: 0.36402405915168806
# Running Train loss: 0.3640155799675163
# Running Train loss: 0.36394293953766343
# Running Train loss: 0.36397227174028013
# Running Train loss: 0.364020100561169
# Running Train loss: 0.36406082172761367
# Running Train loss: 0.36396092819967607
# Running Train loss: 0.3639009694674678
# Running Train loss: 0.36381188320551866
# Running Train loss: 0.36370151257215527
# Running Train loss: 0.36363155121240903
# Running Train loss: 0.36359552665181766
# Running Train loss: 0.36346321974957874
# Running Train loss: 0.3634257338766018
# Running Train loss: 0.36338022523141605
# Running Train loss: 0.3632618774566168
# Running Train loss: 0.3631051191254067
# Running Train loss: 0.36297081973463874
# Running Train loss: 0.36284356491717823
# Running Train loss: 0.3628604713088519
# Running Train loss: 0.36276631315823155
# Running Train loss: 0.362676572126302
# Running Train loss: 0.3626225447386751
# Running Train loss: 0.36249145466398885
# Running Train loss: 0.36243389525594866
# Running Train loss: 0.36234850107803823
# Running Train loss: 0.36224153734882714
# Running Train loss: 0.3621129022439012
# Running Train loss: 0.3619970297990994
# Running Train loss: 0.3618756608332395
# Running Train loss: 0.3619048526360196
# Running Train loss: 0.3619494444068639
# Running Train loss: 0.3618374742613768
# Running Train loss: 0.3618102668676265
# Running Train loss: 0.3619421507955398
# Running Train loss: 0.3622457587732811
# Running Train loss: 0.362223043718728
# Running Train loss: 0.3622039994738839
# Running Train loss: 0.3621144193925501
# Running Train loss: 0.3620587076640571
# Running Train loss: 0.36197001370001897
# Running Train loss: 0.3618257028375222
# Running Train loss: 0.36179880467875875
# Running Train loss: 0.36175009209499875
# Running Train loss: 0.36163646752686684
# Running Train loss: 0.3615262125990424
# Running Train loss: 0.3615136034060002
# Running Train loss: 0.3613962587093377
# Running Train loss: 0.3612465105033838
# Running Train loss: 0.3611929501625955
# Running Train loss: 0.3610965648368306
# Running Train loss: 0.3610646596709643
# Running Train loss: 0.36103428429337703
# Running Train loss: 0.36096437353535993
# Running Train loss: 0.3609177832489791
# Running Train loss: 0.3608388442947783
# Running Train loss: 0.36074432189955896
# Running Train loss: 0.36067830816846896
# Running Train loss: 0.3605879187393857
# Running Train loss: 0.3604593197228591
# Running Train loss: 0.36040556183603195
# Running Train loss: 0.3603716934487884
# Running Train loss: 0.36028819608970597
# Running Train loss: 0.3602031258112602
# Running Train loss: 0.3602357064605911
# Running Train loss: 0.3602089672242862
# Running Train loss: 0.3601436392570717
# Running Train loss: 0.36005447060626555
# Running Train loss: 0.3599053905359682
# Running Train loss: 0.3598568772699614
# Running Train loss: 0.35977581254080027
# Running Train loss: 0.35963953448411357
# Running Train loss: 0.3595473352204461
# Running Train loss: 0.35941245704889296
# Running Train loss: 0.3593283911774817
# Running Train loss: 0.3591919873525955
# Running Train loss: 0.35920890887749085
# Running Train loss: 0.35907602511222103
# Running Train loss: 0.3589432529314901
# Running Train loss: 0.35885788598471613
# Running Train loss: 0.35891830287760973
# Running Train loss: 0.3587699142320855
# Running Train loss: 0.3587075511872348
# Running Train loss: 0.3586022511950368
# Running Train loss: 0.35846297230950414
# Running Train loss: 0.3583971311211226
# Running Train loss: 0.35822897103954277
# Running Train loss: 0.3581067299907638
# Running Train loss: 0.3580070994429328
# Running Train loss: 0.35785738058530436
# Running Train loss: 0.35772734391316025
# Running Train loss: 0.3576302233283402
# Running Train loss: 0.35755600796035353
# Running Train loss: 0.35741969383319366
# Running Train loss: 0.35730310777792024
# Running Train loss: 0.35731292222092526
# Running Train loss: 0.3572498997785263
# Running Train loss: 0.35725104430594434
# Running Train loss: 0.35720553578902037
# Running Train loss: 0.3571110323885049
# Running Train loss: 0.35702663731968753
# Running Train loss: 0.3569071315316352
# Running Train loss: 0.3568484400280058
# Running Train loss: 0.3567364151238875
# Running Train loss: 0.35664355722632063
# Running Train loss: 0.3565617978292567
# Running Train loss: 0.3564877851849489
# Running Train loss: 0.35637491930048076
# Running Train loss: 0.3563039748276125
# Running Train loss: 0.3562202975089087
# Running Train loss: 0.35614224776318276
# Running Train loss: 0.35602073767534753
# Running Train loss: 0.35589274489288447
# Running Train loss: 0.3558133973793194
# Running Train loss: 0.3557882880143422
# Running Train loss: 0.35574570215174656
# Running Train loss: 0.35574764240444506
# Running Train loss: 0.355808572624102
# Running Train loss: 0.3556973009831318
# Running Train loss: 0.3556260169188334
# Running Train loss: 0.3555910590746828
# Running Train loss: 0.35549207671544986
# Running Train loss: 0.3553910759717535
# Running Train loss: 0.35538922790851857
# Running Train loss: 0.3552771788301923
# Running Train loss: 0.3552414527568152
# Running Train loss: 0.35518732644650625
# Running Train loss: 0.35512543721661566
# Running Train loss: 0.35502796406247494
# Running Train loss: 0.35499182007179686
# Running Train loss: 0.35498940819731406
# Running Train loss: 0.3549253866818596
# Running Train loss: 0.35487271305137
# Running Train loss: 0.35474269083387583
# Running Train loss: 0.3547774362066772
# Running Train loss: 0.35468448972202393
# Running Train loss: 0.3546285787652136
# Running Train loss: 0.3546475854479854
# Running Train loss: 0.3545880738143608
# Running Train loss: 0.3545075195108206
# Running Train loss: 0.3543866915960343
# Running Train loss: 0.3542690423640458
# Running Train loss: 0.35411255607024245
# Running Train loss: 0.35397658282959227
# 0.8700

# %% [markdown]
# **⚠️ Your submitted notebook must contain output demonstrating at least 88% accuracy on the development set.**

# %% [markdown]
# ## Problem 5: Pre-trained embeddings (reflection)

# %% [markdown]
# Many neural systems for natural language processing use pre-trained word embeddings, either to augment or to replace randomly initialised task-based embeddings. In this problem, you will investigate whether pre-trained embeddings help your part-of-speech tagger.
#
# The file `glove.pt` contains a PyTorch tensor containing 50-dimensional pre-trained word embeddings from the [GloVe project](https://nlp.stanford.edu/projects/glove/). You can load this tensor using the command
#
# ```
# glove = torch.load('glove.pt')
# ```
#
# and should be able to use it as a drop-in replacement for your randomly initialized word embeddings, assuming that the words in your vocabulary are numbered in the order in which they are found in the training data. Have a look at the documentation of the class [`nn.Embedding`](https://pytorch.org/docs/stable/generated/torch.nn.Embedding.html) to learn how to do this.
#
# Run experiments to assess the effect that pre-trained embeddings have on (a)&nbsp;the accuracy of the tagger, and (b)&nbsp;the speed of learning, i.e., the number of training examples it takes to reach a certain loss. Document your exploration in a short reflection piece (ca. 150&nbsp;words). Respond to the following prompts:
#
# * How did you integrate the pre-trained embeddings into your system? What did you measure? What results did you get?
# * Based on what you know about word embeddings and transfer learning, did you expect your results? How do you explain them?
# * What did you learn? How, exactly, did you learn it? Why does this learning matter?

# %% [markdown]
# *TODO: Insert your report here*
#
# * How did you integrate the pre-trained embeddings into your system? What did you measure? What results did you get?
#
# We integrated the pretraining by instantiating the embeddings with the glove torch tensor. This was done in the TaggerModel. We meassured the accuracy of the pretrained against the original tagger. The pre-trained model reached a much lower running-loss of 0.3539 while the randomly instantiated embeddings reached a running loss of 0.54 after 1 epoch.
#
# * Based on what you know about word embeddings and transfer learning, did you expect your results? How do you explain them?
#
# Yes, we expected the running loss to decrease much faster with the pretrained embeddings. This is because transfer learning makes the model focus more on the learning of the linear and relu layers instead of learning the embedding layers.
#
# * What did you learn? How, exactly, did you learn it? Why does this learning matter?
#
# In this lab we learned about the ideas behind tagging, baselines, module lists and more on how to use the output of our models. We also found it intresting to see the pre-trained embeddings and how they work by decreasing the learning time.

# %% [markdown]
# **🥳 Congratulations on finishing this lab! 🥳**
